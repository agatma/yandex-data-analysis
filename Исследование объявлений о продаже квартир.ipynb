# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
# <b>Мадихан, привет!</b>
#
# Меня зовут Евгений Дащенко, и я буду проверять твой проект. Предлагаю общаться на «ты» 😊 Но если это не удобно - дай знать, и мы перейдем на "вы".
#
# Моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать аналитиком данных. Ты уже проделал большую работу над проектом, но давай сделаем его еще лучше. Ниже ты найдешь мои комментарии - пожалуйста, не перемещай, не изменяй и не удаляй их. Я буду использовать цветовую разметку:
#
# <div class="alert alert-danger">
# <b>Комментарий ревьюера:</b> Так выделены самые важные замечания. Без их отработки проект не будет принят. </div>
#
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b> Так выделены небольшие замечания. Одна-два таких замечания в проекте допустимы, но если их будет больше - тебе будет необходимо внести исправления. Это как тестовое задание при приеме на работу: очень много мелких ошибок могут стать причиной отказа кандидату.
#
# </div>
#
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b> Так я выделяю все остальные комментарии.</div>
#
# Давай работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комменатри — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
# <div class="alert alert-info"> <b>Комментарий студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее.

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Изучение-данных-из-файла" data-toc-modified-id="Изучение-данных-из-файла-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Проверка-распределения-ключевого-показателя-квартиры---цены---перед-удалением-строк-с-пустыми-значениями-в-столбцах-с-названием-населенного-пункта-и-общим-кол-вом-этажей-в-доме" data-toc-modified-id="Проверка-распределения-ключевого-показателя-квартиры---цены---перед-удалением-строк-с-пустыми-значениями-в-столбцах-с-названием-населенного-пункта-и-общим-кол-вом-этажей-в-доме-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Проверка распределения ключевого показателя квартиры - цены - перед удалением строк с пустыми значениями в столбцах с названием населенного пункта и общим кол-вом этажей в доме</a></span><ul class="toc-item"><li><span><a href="#Промежуточные-выводы" data-toc-modified-id="Промежуточные-выводы-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Промежуточные выводы</a></span></li></ul></li><li><span><a href="#Заполнение-пустых-значений-в-столбцах" data-toc-modified-id="Заполнение-пустых-значений-в-столбцах-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Заполнение пустых значений в столбцах</a></span></li><li><span><a href="#Привод-данных-к-нужным-типам" data-toc-modified-id="Привод-данных-к-нужным-типам-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Привод данных к нужным типам</a></span></li></ul></li><li><span><a href="#Расчёты-и-добавление-результатов-в-таблицу" data-toc-modified-id="Расчёты-и-добавление-результатов-в-таблицу-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Расчёты и добавление результатов в таблицу</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Постройте-гистограммы-для-каждого-параметра." data-toc-modified-id="Изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Постройте-гистограммы-для-каждого-параметра.-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучите следующие параметры: площадь, цена, число комнат, высота потолков. Постройте гистограммы для каждого параметра.</a></span><ul class="toc-item"><li><span><a href="#Промежуточные-выводы" data-toc-modified-id="Промежуточные-выводы-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Промежуточные выводы</a></span></li></ul></li><li><span><a href="#Изучите-время-продажи-квартиры.-Постройте-гистограмму.-Посчитайте-среднее-и-медиану.-Опишите,-сколько-обычно-занимает-продажа.-Когда-можно-считать,-что-продажи-прошли-очень-быстро,-а-когда-необычно-долго?" data-toc-modified-id="Изучите-время-продажи-квартиры.-Постройте-гистограмму.-Посчитайте-среднее-и-медиану.-Опишите,-сколько-обычно-занимает-продажа.-Когда-можно-считать,-что-продажи-прошли-очень-быстро,-а-когда-необычно-долго?-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?</a></span><ul class="toc-item"><li><span><a href="#Промежуточные-выводы" data-toc-modified-id="Промежуточные-выводы-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Промежуточные выводы</a></span></li></ul></li><li><span><a href="#Уберите-редкие-и-выбивающиеся-значения.-Опишите,-какие-особенности-обнаружили." data-toc-modified-id="Уберите-редкие-и-выбивающиеся-значения.-Опишите,-какие-особенности-обнаружили.-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили.</a></span><ul class="toc-item"><li><span><a href="#Промежуточные-выводы" data-toc-modified-id="Промежуточные-выводы-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Промежуточные выводы</a></span></li></ul></li><li><span><a href="#Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?-Изучите,-зависит-ли-цена-от-площади,-числа-комнат,-удалённости-от-центра.-Изучите-зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом.-Также-изучите-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года." data-toc-modified-id="Какие-факторы-больше-всего-влияют-на-стоимость-квартиры?-Изучите,-зависит-ли-цена-от-площади,-числа-комнат,-удалённости-от-центра.-Изучите-зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом.-Также-изучите-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года.-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года.</a></span><ul class="toc-item"><li><span><a href="#Какие-факторы-больше-всего-влияют-на-стоимость-квартиры.-Изучите,-зависит-ли-цена-от-площади,-числа-комнат,-удалённости-от-центра." data-toc-modified-id="Какие-факторы-больше-всего-влияют-на-стоимость-квартиры.-Изучите,-зависит-ли-цена-от-площади,-числа-комнат,-удалённости-от-центра.-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Какие факторы больше всего влияют на стоимость квартиры. Изучите, зависит ли цена от площади, числа комнат, удалённости от центра.</a></span><ul class="toc-item"><li><span><a href="#Промежуточные-выводы" data-toc-modified-id="Промежуточные-выводы-4.4.1.1"><span class="toc-item-num">4.4.1.1&nbsp;&nbsp;</span>Промежуточные выводы</a></span></li></ul></li><li><span><a href="#Изучите-зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом." data-toc-modified-id="Изучите-зависимость-цены-от-того,-на-каком-этаже-расположена-квартира:-первом,-последнем-или-другом.-4.4.2"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом.</a></span><ul class="toc-item"><li><span><a href="#Промежуточные-выводы" data-toc-modified-id="Промежуточные-выводы-4.4.2.1"><span class="toc-item-num">4.4.2.1&nbsp;&nbsp;</span>Промежуточные выводы</a></span></li></ul></li><li><span><a href="#Изучите-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года." data-toc-modified-id="Изучите-зависимость-от-даты-размещения:-дня-недели,-месяца-и-года.-4.4.3"><span class="toc-item-num">4.4.3&nbsp;&nbsp;</span>Изучите зависимость от даты размещения: дня недели, месяца и года.</a></span><ul class="toc-item"><li><span><a href="#Промежуточные-выводы" data-toc-modified-id="Промежуточные-выводы-4.4.3.1"><span class="toc-item-num">4.4.3.1&nbsp;&nbsp;</span>Промежуточные выводы</a></span></li></ul></li></ul></li><li><span><a href="#Выберите-10-населённых-пунктов-с-наибольшим-числом-объявлений.-Посчитайте-среднюю-цену-квадратного-метра-в-этих-населённых-пунктах.-Выделите-среди-них-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-жилья.-Эти-данные-можно-найти-по-имени-в-столбце-'locality_name'." data-toc-modified-id="Выберите-10-населённых-пунктов-с-наибольшим-числом-объявлений.-Посчитайте-среднюю-цену-квадратного-метра-в-этих-населённых-пунктах.-Выделите-среди-них-населённые-пункты-с-самой-высокой-и-низкой-стоимостью-жилья.-Эти-данные-можно-найти-по-имени-в-столбце-'locality_name'.-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите среди них населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце 'locality_name'.</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Промежуточные-выводы" data-toc-modified-id="Промежуточные-выводы-4.5.0.1"><span class="toc-item-num">4.5.0.1&nbsp;&nbsp;</span>Промежуточные выводы</a></span></li></ul></li></ul></li><li><span><a href="#Изучите-предложения-квартир:-для-каждой-квартиры-есть-информация-о-расстоянии-до-центра.-Выделите-квартиры-в-Санкт-Петербурге-('locality_name').-Ваша-задача-—-выяснить,-какая-область-входит-в-центр.-Создайте-столбец-с-расстоянием-до-центра-в-километрах:-округлите-до-целых-значений.-После-этого-посчитайте-среднюю-цену-для-каждого-километра.-Постройте-график:-он-должен-показывать,-как-цена-зависит-от-удалённости-от-центра.-Определите-границу,-где-график-сильно-меняется-—-это-и-будет-центральная-зона." data-toc-modified-id="Изучите-предложения-квартир:-для-каждой-квартиры-есть-информация-о-расстоянии-до-центра.-Выделите-квартиры-в-Санкт-Петербурге-('locality_name').-Ваша-задача-—-выяснить,-какая-область-входит-в-центр.-Создайте-столбец-с-расстоянием-до-центра-в-километрах:-округлите-до-целых-значений.-После-этого-посчитайте-среднюю-цену-для-каждого-километра.-Постройте-график:-он-должен-показывать,-как-цена-зависит-от-удалённости-от-центра.-Определите-границу,-где-график-сильно-меняется-—-это-и-будет-центральная-зона.-4.6"><span class="toc-item-num">4.6&nbsp;&nbsp;</span>Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге ('locality_name'). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона.</a></span><ul class="toc-item"><li><span><a href="#Промежуточные-выводы:" data-toc-modified-id="Промежуточные-выводы:-4.6.1"><span class="toc-item-num">4.6.1&nbsp;&nbsp;</span>Промежуточные выводы:</a></span></li></ul></li><li><span><a href="#Выделите-сегмент-квартир-в-центре.-Проанализируйте-эту-территорию-и-изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Также-выделите-факторы,-которые-влияют-на-стоимость-квартиры-(число-комнат,-этаж,-удалённость-от-центра,-дата-размещения-объявления).-Сделайте-выводы.-Отличаются-ли-они-от-общих-выводов-по-всему-городу?" data-toc-modified-id="Выделите-сегмент-квартир-в-центре.-Проанализируйте-эту-территорию-и-изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-Также-выделите-факторы,-которые-влияют-на-стоимость-квартиры-(число-комнат,-этаж,-удалённость-от-центра,-дата-размещения-объявления).-Сделайте-выводы.-Отличаются-ли-они-от-общих-выводов-по-всему-городу?-4.7"><span class="toc-item-num">4.7&nbsp;&nbsp;</span>Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?</a></span><ul class="toc-item"><li><span><a href="#Выделите-сегмент-квартир-в-центре." data-toc-modified-id="Выделите-сегмент-квартир-в-центре.-4.7.1"><span class="toc-item-num">4.7.1&nbsp;&nbsp;</span>Выделите сегмент квартир в центре.</a></span></li><li><span><a href="#Проанализируйте-эту-территорию-и-изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков." data-toc-modified-id="Проанализируйте-эту-территорию-и-изучите-следующие-параметры:-площадь,-цена,-число-комнат,-высота-потолков.-4.7.2"><span class="toc-item-num">4.7.2&nbsp;&nbsp;</span>Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков.</a></span><ul class="toc-item"><li><span><a href="#Промежуточные-выводы" data-toc-modified-id="Промежуточные-выводы-4.7.2.1"><span class="toc-item-num">4.7.2.1&nbsp;&nbsp;</span>Промежуточные выводы</a></span></li></ul></li><li><span><a href="#Также-выделите-факторы,-которые-влияют-на-стоимость-квартиры-(число-комнат,-этаж,-удалённость-от-центра,-дата-размещения-объявления)" data-toc-modified-id="Также-выделите-факторы,-которые-влияют-на-стоимость-квартиры-(число-комнат,-этаж,-удалённость-от-центра,-дата-размещения-объявления)-4.7.3"><span class="toc-item-num">4.7.3&nbsp;&nbsp;</span>Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления)</a></span><ul class="toc-item"><li><span><a href="#Промежуточные-выводы" data-toc-modified-id="Промежуточные-выводы-4.7.3.1"><span class="toc-item-num">4.7.3.1&nbsp;&nbsp;</span>Промежуточные выводы</a></span></li></ul></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Здорово, когда есть вступление в сам проект, каждый сможет быстрее разобраться с тем о чем сам проект.
#
# </div>

# %% [markdown]
# ## Изучение данных из файла

# %%
#P.S Good_luck and god bless you!

#0. Импортируем необходимые библиотеки. 

#Pandas для обработки и работы с данными
import pandas as pd

#Matplotlib для графического представления данных
import matplotlib.pyplot as plt

#Numpy для математических операций 
import numpy as np

#Warnings для исключения бесполезных предупреждений
import warnings
warnings.filterwarnings('ignore')


#1. Открываем файл с помощью функции pd.read_csv
#Дополнительно используем конструкцию try and except, чтобы файл открывался либо с сервера, либо с локального ПК
try:
    df = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
except:
    df = pd.read_csv('real_estate_data.csv', sep='\t')

#2. Устанавливаем отображения количества столбцов на экране. Также укажем удобный формат вывода для чисел с плавающей точкой
     
pd.options.display.max_columns = 40
pd.set_option('display.float_format', lambda x: '%.3f' % x)

#3. Функия isna() определяет наличие пропусков в таблице. Возвращает true или false - это 1 или 0. 
#С помощью функции mean() находим среднее значение от 0 до 1 в каждом столбце. Если 0 - значит пропусков нет. Если 1, значит 100% пропусков
#Дальше используем метод round, чтобы округлить значения. Умножаем на 100 и показываем до 2 знаков после запятой. 
#Чтобы раскрасить значения используем метод style.backgroud_gradient. В параметрах говорим, что отмечай значения от 10% до 90%
pd.DataFrame(round((df.isna().mean()*100),2)).style.background_gradient('PuBu', low=0.1, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_de0c3e0e_b486_11eb_acab_02420a393cd9row0_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_de0c3e0e_b486_11eb_acab_02420a393cd9row1_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_de0c3e0e_b486_11eb_acab_02420a393cd9row2_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_de0c3e0e_b486_11eb_acab_02420a393cd9row3_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_de0c3e0e_b486_11eb_acab_02420a393cd9row4_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_de0c3e0e_b486_11eb_acab_02420a393cd9row5_col0 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_de0c3e0e_b486_11eb_acab_02420a393cd9row6_col0 {
#             background-color:  #f7f0f7;
#             color:  #000000;
# ...

# %% [markdown]
# ### Вывод

# %% [markdown]
# 1. В столбцах locality_name и floors_total меньше 1% пропусков. Удаление строк с пустыми значениями в данных столбцах сильно не повлияет на общее распределение ключевого показателя исследования.
# 2. Столбец is_apartment имеет больше 85% пропусков. С помощью метода value_counts() определили, что в данном столбце только два значения True and False. Если человек не указал, что это апартаменты, значит квартира не является апартаментами. Yes, cap. Поэтому значения можно заполнить False.
# 3. Столбец ceiling_height имеет 38% пропусков. Данный параметр не повлияет на наше исследование - можем заполнить значения медианой по столбцу.
# 4. Столбец living_area и kitchen_area нужно заполнить медианными значениями в зависимости от двух переменных(количество комнат и соотношения жилой площади к общей, а также площади кухни к общей площади).
# 5. Столбец balcony имеет 48% пропусков. Если при заполнении профиля продавец не указал наличие балкона (а это увеличивает стоимость), то с вероятностью 99% его нет. Поэтому пустые значения можно заполнить нулем.
# 6. Столбцы airports_nearest, cityCenters_nearest, parks_nearest, ponds_nearest, ponds_around3000, parks_around3000, тоже имеют пропуски: от 23 до 65%. Эти пропуски появились при заполнении данных картографическим сервисом. Любое заполнение пропусков может сильно исказить данные.
# 7. Столбец days_exposition (сколько дней было размещено объявление (от публикации до снятия) имеет 13% пропусков. В уникальных значениях столбца нет нулей. Поэтому, пустые значения заполним нулем, чтобы показать, что данное объявление не было снято с продажи (99% вероятность, что просто забыли снять, а продали в другом сервисе (авито, циан и т.д).

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Достаточно детально изучили наши первичные данные, давай теперь их обработаем.
#
# ---
#
# Отличный и удобный подход для визуализации долей пропусков.
#
# </div>

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Проверка распределения ключевого показателя квартиры - цены - перед удалением строк с пустыми значениями в столбцах с названием населенного пункта и общим кол-вом этажей в доме

# %%
#Стром ось, по df. Указываем, чтобы в df остались только строки с пустыми значениями в столбце locality_name.
#Строим по этим данным график типа гистограмма. Тип - ступенчатая. Количесто корзин = 50. 
ax = df[df['locality_name'].isnull()].plot(kind='hist', y='last_price', histtype='step', bins=50, range=(0, 45000000), label='delete_locality_name')

#Тоже самое делаем со столбцом floors_total. Плюс на график добавляем ранее созданную ось
df[df['floors_total'].isnull()].plot(kind='hist', y='last_price', histtype='step', bins=50, label='delete_floors_total', ax=ax, range=(0, 45000000))

#Строим гистограмму по неочищенному от пустых значений df
df.plot(kind='hist', y='last_price', range=(0, 45000000),bins=50, label='Стоимость квартиры')
plt.title('Распределение цены квартиры')
plt.xlabel('Цена')
plt.ylabel('Частотность')
plt.show()

#Удаление пустых значений в столбце floors_total и locality_name. 
df.dropna(subset=['floors_total', 'locality_name'], inplace=True)

# %% [markdown]
# #### Промежуточные выводы

# %% [markdown]
# Удаление строчек с пустыми значениями в столбцах floors_total и locality_name сильно не повлияют на общее распределение ключевого показателя исследования.

# %% [markdown]
# ### Заполнение пустых значений в столбцах

# %%
#0. Заполнение пустых значений в столбце is_apartment
df['is_apartment'] = df['is_apartment'].fillna(False)

#1. Заполнение пустых значений в столбце balcony
df['balcony'] = df['balcony'].fillna(0)

#2. Заполнение пустых значений в столбце days_exposition
df['days_exposition'] = df['days_exposition'].fillna(0)

#3. Заполнение пустых значений в столбце celing_height медианным значением по столбцу
df['ceiling_height'] = df['ceiling_height'].fillna(df['ceiling_height'].median())

#4. Заполнение пустых значений в столбцах living_area и kitchen_area с помощью медианного коэффициента. 


#Создадим столбцы соотношение жилой и общей площади, а также отношение площади кухни к общей.
df['liv_coef'] = df['living_area'] / df['total_area']
df['kit_coef'] = df['kitchen_area'] / df['total_area']

#Создадим словари
liv_coef_dict = df.groupby('rooms')['liv_coef'].median().to_dict()
kit_coef_dict = df.groupby('rooms')['kit_coef'].median().to_dict()

#Заполняем пустые значения в столбцах перемноженными данными 
df['living_area'] = (df['rooms'].map(liv_coef_dict))*df['total_area']
df['kitchen_area'] = (df['rooms'].map(kit_coef_dict))* df['total_area']

#Заполняем оставшиеся пустые значения нулем. 
df['kitchen_area'] = df['kitchen_area'].fillna(0)

pd.DataFrame(round((df.isna().mean()*100),2)).style.background_gradient('PuBu', low=0.1, high=0.9)
# Out:
# <style  type="text/css" >
#     #T_e46eb876_b486_11eb_acab_02420a393cd9row0_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_e46eb876_b486_11eb_acab_02420a393cd9row1_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_e46eb876_b486_11eb_acab_02420a393cd9row2_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_e46eb876_b486_11eb_acab_02420a393cd9row3_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_e46eb876_b486_11eb_acab_02420a393cd9row4_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_e46eb876_b486_11eb_acab_02420a393cd9row5_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_e46eb876_b486_11eb_acab_02420a393cd9row6_col0 {
#             background-color:  #f8f1f8;
#             color:  #000000;
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# В том числе метод `fillna` и `astype` можно применять к нескольким столбцам одновременно.
#
# Если столбцов более 2–ух, то рекомендую применять цикл `for`.
#
# Пример:
#
# `df.astype({ "col1": "float64", "col2": "int64"})`
#
# </div>

# %% [markdown]
# ### Привод данных к нужным типам

# %%
#0. Доработка значений даты и времени
df['first_day_exposition'] = pd.to_datetime(df['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')

#1. Смена формата данных в столбцах  floors_total и balcony с типом float

df[['floors_total','balcony']] = df[['floors_total','balcony']].astype('int')

#2. Отсечение лишних данных в столбце locality_name по типу 'поселок, деревня'
#df['locality_name'].unique()

#Создаём фунцию. На вход она принимает строку. Проходит по каждой букве и когда встречает регист
#возвращает строку начиная с этой буквы и до конца строки
def no_upper(string):
    for i in range(len(string)):
        if string[i].isupper():
            return string[i: len(string)]
df['locality_name'] = df['locality_name'].apply(no_upper)

#Проверка данных
#display(df.sample(15,random_state=1))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23565 entries, 0 to 23698
# Data columns (total 24 columns):
# total_images            23565 non-null int64
# last_price              23565 non-null float64
# total_area              23565 non-null float64
# first_day_exposition    23565 non-null datetime64[ns]
# rooms                   23565 non-null int64
# ceiling_height          23565 non-null float64
# floors_total            23565 non-null int64
# living_area             23565 non-null float64
# floor                   23565 non-null int64
# is_apartment            23565 non-null bool
# studio                  23565 non-null bool
# open_plan               23565 non-null bool
# kitchen_area            23565 non-null float64
# balcony                 23565 non-null int64
# locality_name           23565 non-null object
# airports_nearest        18041 non-null float64
# cityCenters_nearest     18064 non-null float64
# parks_around3000        18065 non-null float64
# ...

# %% [markdown]
# # Выводы по предобработки данных

# %% [markdown]
# 1. Пропуски в столбцах заполнены
# 2. Типы данных успешно изменены
# 3. Значение даты и времени доработаны
# 4. Названия городов и поселков скорректированы

# %% [markdown]
# ## Расчёты и добавление результатов в таблицу

# %%
#0. Добавление столбцов. 
#Цена квадратного метра
df['square_meter_price'] = df['last_price']/ df['total_area']

#Добавления столбцов: день недели, месяц и год публикации объявления;
df['weekday_of_exposition'] = df['first_day_exposition'].dt.weekday
df['month_of_exposition'] = df['first_day_exposition'].dt.month
df['year_of_exposition'] = df['first_day_exposition'].dt.year

#1. Добавление этажа квартиры: варианты — первый, последний, другой;
def category_floor(column): 
    floor = column['floor'] #Создаем переменную floor в функции, которая будет искать столбец в floor в df и сохранять значение
    floor_total = column['floors_total'] #Такая же история со столбцов floors_total
    if floor == 1:
        return 'первый'
    elif floor == floor_total:
        return 'последний'
    return 'другой'
df['floor_category'] = df.apply(category_floor, axis=1) #Применяем функцию к df. Указываем, чтобы работала со столбцами axis=1

#2. Столбцы с соотношением жилой и общей площади, а также отношением площади кухни к общей уже добавлены в разделе предобработка

df.head()
# Out:
#    total_images   last_price  total_area first_day_exposition  rooms  \
# 0            20 13000000.000     108.000           2019-03-07      3
# 1             7  3350000.000      40.400           2018-12-04      1
# 2            10  5196000.000      56.000           2015-08-20      2
# 3             0 64900000.000     159.000           2015-07-24      3
# 4             2 10000000.000     100.000           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0           2.700            16       68.238      8         False   False
# 1           2.650            11       19.499      1         False   False
# 2           2.650             5       32.786      4         False   False
# 3           2.650            14      100.461      9         False   False
# 4           3.030            14       58.547     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Мы достаточно детально обработали наши данные и добавили все необходимые значения в нашу выборку. Давай теперь проведём анализ.
#
# </div>

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Изучите следующие параметры: площадь, цена, число комнат, высота потолков. Постройте гистограммы для каждого параметра.

# %%
#1. Строим функцию, которая будет определять число корзин в гистограмме. 
def my_bins(df,value):
    
    if df[value].max() > 100: #Если значение по столбцу больше 100, то возвращаем 50 корзин
        return 50
    elif df[value].max() > 500: #Если значение по столбцу больше 500, то возвращаем 100 корзин
        return  100
    elif df[value].max() > 1000: #Если значение по столбцу больше 1000, то возвращаем 200 корзин
        return  200
    else: return 20

#2. Строим функцию, которая будет строить гистограммы по столбцам из списка
def hist_list(df,col):
    #Строим столбец, очищенный от выбросов (от 0.05 квантиля до 0.95 квантиля. То есть исключаем 5% данных с двух сторон)
    X_1 = df.loc[(df[col] >= df[col].quantile(.05))&(df[col] <= df[col].quantile(.95)),col]
    plt.figure(figsize =(6, 4))
    #Строим гистограмму по нашему столбцу X_1
    hist = X_1.plot(
                kind='hist',
                bins=my_bins(df, col), 
                alpha=0.5, 
                ec='black',
                color='blueviolet',
                )
    plt.axvline(x=X_1.median(), #Добавление линий на гистограмму. Говорим, покажи на гистограмме медиану по столбцу
                linewidth=3, #Ширину линии сделай - 3
                color='green', # Цвет зеленый
                linestyle='--') #Стиль линии
    plt.axvline(x=X_1.quantile(.05),
                linewidth=3, 
                color='black', 
                linestyle='--')
    plt.axvline(x=X_1.quantile(.95),
                linewidth=3, 
                color='black', 
                linestyle='--')
    plt.title('Распределение по столбцу ' + col)
    plt.xlabel('Значение')
    plt.ylabel('Частота')
    plt.grid()
    plt.show()
    print(df[col].describe())
    print('--------------------------------------------------------------')
#Строим цикл, чтобы с помощью функции автоматизировать построение гистограмм
list_of_column = ['total_area', 'last_price', 'rooms', 'ceiling_height']
for column in list_of_column:
    hist_list(df, column)
# Out:
# count   23565.000
# mean       60.323
# std        35.657
# min        12.000
# 25%        40.000
# 50%        52.000
# 75%        69.700
# max       900.000
# Name: total_area, dtype: float64
# --------------------------------------------------------------
# count       23565.000
# mean      6540058.260
# std      10910934.722
# min         12190.000
# 25%       3400000.000
# 50%       4646000.000
# 75%       6790000.000
# max     763000000.000
# Name: last_price, dtype: float64
# --------------------------------------------------------------
# count   23565.000
# mean        2.071
# std         1.079
# min         0.000
# 25%         1.000
# 50%         2.000
# 75%         3.000
# max        19.000
# Name: rooms, dtype: float64
# --------------------------------------------------------------
# count   23565.000
# mean        2.725
# std         0.991
# min         1.000
# 25%         2.600
# 50%         2.650
# 75%         2.700
# max       100.000
# ...

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Здорово, что получилось применить автоматизацию построения графиков 👍
#
# Теперь в нужный момент мы сможем применить данный инструмент.
#
# ---
#
# Отличная функция для визуализации наших графиков 😊
#
# Если вдруг тебе понравилась тема визуализации, рекомендую посмотреть на библиотеку `seaborn`
#
# </div>

# %% [markdown]
# #### Промежуточные выводы

# %% [markdown]
# Типичная квартира в выборке: 2-х комнатная квартира с потолками 2.65 метра, площадью 52 квадратных метра и ценой -  4 646 000 рублей

# %% [markdown]
# ### Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?

# %%
#Изучаем время продажи. 
X_2 = df['days_exposition'] #Сохраняем данные по длительности продажи квартиры в переменную.

#Строим по переменной гистограмму
hist = X_2.plot(
    kind='hist', 
    bins=my_bins(df, 'days_exposition'),
    alpha=0.5,
    ec='black',
    color='blueviolet',
)
#Добавляем линии с отображением 25%, 50% и 75% квартириля. 
plt.axvline(x=X_2.median(),
            linewidth=3, 
            color='green', 
            linestyle='--')    
plt.axvline(x=X_2.quantile(.25),
            linewidth=3, 
            color='black', 
            linestyle='--')
plt.axvline(x=X_2.quantile(.75),
            linewidth=3, 
            color='black', 
            linestyle='--')

#Указываем название гистограммы и название осей.
plt.title('Распределение по столбцу ' + 'days_exposition')
plt.xlabel('Значение')
plt.ylabel('Частота')
plt.grid()
plt.show()

#Строим boxplot по длительности продажи квартиры
plt.figure(figsize =(6, 2))
plt.boxplot(X_2,
            notch=True, 
            sym="o", 
            vert=False,
            widths = 0.1, 
            patch_artist = True)
plt.ylabel('Ящие с усами ' + 'days_exposition')
plt.tick_params(axis = 'both', 
                which = 'major',
                direction = 'inout',
                length = 20,
                width = 4,
                color = 'blueviolet',
                pad = 10,
                labelsize = 15,
                labelcolor = 'black') 
plt.grid()
plt.show()

display(X_2.describe())
print('--------------------------------------------------------------')

#Удалим выбросы в данных (все значения, которые превышают сумму третьего квартиля и полтора интерквартального размаха).
interquartile_range = (df['days_exposition'].quantile(.75) - df['days_exposition'].quantile(.25)) * 1.5
good_days_exposition = df.loc[df['days_exposition'] <= interquartile_range, 'days_exposition']

#Строим гистограмму по данным, очищенных от выбросов. 
hist = good_days_exposition.plot(
    kind='hist', 
    bins=100, 
    alpha=0.5, 
    ec='black',
    color='blueviolet',
)
#Добавляем на данные линии с 25%, 50%, 75% квартилями. 
plt.axvline(x=good_days_exposition.median(),
            linewidth=3, 
            color='green', 
            linestyle='--')    
plt.axvline(x=good_days_exposition.quantile(.25),
            linewidth=3, 
            color='black', 
            linestyle='--')
plt.axvline(x=good_days_exposition.quantile(.75),
            linewidth=3, 
            color='black', 
            linestyle='--')  
plt.title('Распределение по столбцу ' + 'good_days_exposition')
plt.xlabel('Значение')
plt.ylabel('Частота')
plt.grid()
plt.show()

#Строим boxplot по очищенным данным
plt.figure(figsize =(6, 2))
plt.boxplot(good_days_exposition,
            notch=True, 
            sym="o", 
            vert=False,
            widths = 0.1, 
            patch_artist = True)
plt.ylabel('Ящие с усами ' + 'good_days_exposition')
plt.tick_params(axis = 'both', 
                which = 'major',
                direction = 'inout',
                length = 20,
                width = 4,
                color = 'blueviolet',
                pad = 10,
                labelsize = 15,
                labelcolor = 'black' 
             ) 
plt.grid()
plt.show()

display(good_days_exposition.describe())

#Находим выбросы в очищенных данных 
good_interquartile_range = (good_days_exposition.quantile(.75) - good_days_exposition.quantile(.25)) * 1.5
good_interquartile_range
# Out:
# count   23565.000
# mean      156.420
# std       213.517
# min         0.000
# 25%        22.000
# 50%        73.000
# 75%       198.000
# max      1580.000
# Name: days_exposition, dtype: float64
# --------------------------------------------------------------
# count   19084.000
# mean       71.661
# std        68.784
# min         0.000
# 25%        13.000
# 50%        51.000
# 75%       112.000
# max       264.000
# Name: days_exposition, dtype: float64
# 148.5

# %% [markdown]
# <div class="alert alert-warning">
# <b>Комментарий ревьюера:</b>
#
# Лучше всего конечно не делать такие объемные ячейки с кодом.
#
# Почему ?
#
# Это создает ряд неудобностей:
#
# - код тяжелее и медлее изучать
# - возникают неудобства в коммуникации, будет не совсем удобно изучать мои комментарии и потом на них отвечать
#
# Поэтому рекомендую делать методы в отдельных ячейках, если это например не одни и те же способы.
#
# </div>

# %% [markdown]
# #### Промежуточные выводы

# %% [markdown]
# По очищенным от выбросов данным, продажа квартиры в среднем занимает 51 день. Если продажа квартиры занимает больше 148 дней (1,5 межквартильного размаха), то можно сказать, что продажа квартиры необычно долгая. По необычно быстрой продажи нет возможности определить, так как выбросов в сторону минимальных значений в очищенных данных не наблюдается. Диаграмма имеет длинный хвост и короткий клюв. Если я не попал в понятие, то прошу винить Nicki Minaj

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Также мы можем увеличить сам график, чтобы его было удобнее изучать с помощью метода `plt.figure(figsize=(10,7))`
#
# </div>

# %% [markdown]
# ### Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили.

# %%
#Сохраняем все столбцы формата int и float в список
column_names = ['total_images', 'last_price', 'total_area','rooms', 
                'ceiling_height', 'floors_total', 'living_area', 'floor', 'kitchen_area', 'balcony', 
                'airports_nearest','cityCenters_nearest', 'parks_around3000', 'parks_nearest',
               'days_exposition', 'square_meter_price']
print('')
print('-------------------------------------Сырой df----------------------------------------------------------------')
display(df.describe())

#Создаем цикл, который в каждом столбце сохраняет данные от 1 квартиля до 99%. 
#Тем самым мы удалим выбросы на минимальных и максимальных значениях.
for column in column_names:
    df_good = df.loc[(df[column] > df[column].quantile(.01)) & (df[column] < df[column].quantile(.99))]
print('')
print('-------------------------------------Мокрый df---------------------------------------------------------------')
display(df_good.describe())
# Out:
# -------------------------------------Сырой df----------------------------------------------------------------
#        total_images    last_price  total_area     rooms  ceiling_height  \
# count     23565.000     23565.000   23565.000 23565.000       23565.000
# mean          9.878   6540058.260      60.323     2.071           2.725
# std           5.681  10910934.722      35.657     1.079           0.991
# min           0.000     12190.000      12.000     0.000           1.000
# 25%           6.000   3400000.000      40.000     1.000           2.600
# 50%           9.000   4646000.000      52.000     2.000           2.650
# 75%          14.000   6790000.000      69.700     3.000           2.700
# max          50.000 763000000.000     900.000    19.000         100.000
#
#        floors_total  living_area     floor  kitchen_area   balcony  \
# count     23565.000    23565.000 23565.000     23565.000 23565.000
# mean         10.676       35.629     5.878         9.644     0.594
# ...

# %% [markdown]
# #### Промежуточные выводы

# %% [markdown]
# 1. В столбце last_price среднее значение изменилось значительно. Медиана изменилась на 1%.
# 2. Особенность: при удалении выбросов медиана практически не меняется, а среднее значение скачет на 5-10%
# 3. Данные, которые были получены с помощью картографических сервисов, остались практически без изменений.

# %% [markdown]
# ### Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от площади, числа комнат, удалённости от центра. Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом. Также изучите зависимость от даты размещения: дня недели, месяца и года.

# %% [markdown]
# #### Какие факторы больше всего влияют на стоимость квартиры. Изучите, зависит ли цена от площади, числа комнат, удалённости от центра.

# %%
#Отобразим столбец корреляции по стоимости квартир. 
display(df_good.corr()['last_price'].sort_values())

#Построим диграмму рассеивания по показателям
corr_price = df_good[['last_price', 'rooms', 'total_area', 'living_area', 'cityCenters_nearest']]
pd.plotting.scatter_matrix(corr_price, figsize=(15, 15), marker='x', alpha=0.4, color='black') #Черный цвет - и расхождений в графике нет
display(plt.show())
# Out:
# cityCenters_nearest     -0.305
# kit_coef                -0.144
# ponds_nearest           -0.101
# studio                  -0.045
# airports_nearest        -0.036
# year_of_exposition      -0.032
# open_plan               -0.020
# weekday_of_exposition   -0.009
# month_of_exposition      0.002
# parks_nearest            0.011
# balcony                  0.016
# liv_coef                 0.024
# floors_total             0.026
# is_apartment             0.033
# floor                    0.050
# days_exposition          0.068
# ceiling_height           0.109
# total_images             0.147
# ponds_around3000         0.168
# parks_around3000         0.179
# rooms                    0.535
# square_meter_price       0.599
# kitchen_area             0.746
# living_area              0.825
# total_area               0.840
# last_price               1.000
# Name: last_price, dtype: float64
# None

# %% [markdown]
# ##### Промежуточные выводы

# %% [markdown]
# Задача: Какие факторы больше всего влияют на стоимость квартиры. Изучите, зависит ли цена от площади, числа комнат, удалённости от центра.
#
# Ответ:
# 1. Зависимость между ценой и площадью квартиры достаточно сильнаая. Коэффициент положительной корреляция Пирсона - 0.825. С увеличением площади квартиры увеличивается стоимость квартиры.
# 2. Стоит также отметить полную корреляцию между жилой площадью квартиры и общей площадью квартиры. Что подтверждает корректность данных.
# 2. Присутствует зависимость между ценой и площадью одно-, двух- и трехкомнатных квартир (см. график - первая строка, второй столбец). Стоимость многокомнатных квартир малопредсказуема - прямолинейной зависимости нет.
# 3. Удаленность от центра не влияет на стоимость квартиры. Коэффицент корреляции Пирсона: -0.305

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Хорошие и логичные комментарии. Очень важно строить график корреляции между переменными, ведь может произойти такая ситуация, что расчет у нас очень сильный а на графике абсолютно другая картина.
#
# ---
#
# В том числе можно было построить матрицу корреляции между нужными нам переменными.
#
# И визуализировать её с помощью метода `heatmap` из библиотеки `seaborn`.
#
# </div>

# %% [markdown]
# #### Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом.

# %%
#Сохраняем название этажей в категории в список
floor_name = ['первый', 'последний', 'другой']

#Создаём цикл, который проходит по названию этажа в категории и строит график по цене.
for name in floor_name:
    df.loc[df['floor_category'] == name]['last_price'].plot(grid=True, 
                                                                      ylim=0, 
                                                                      legend=True, 
                                                                      label=name,
                                                                      color='blueviolet',
                                                                      alpha=.7)
    plt.title('Цена квартир. Этаж ' + name)
    plt.xlabel('Значение')
    plt.ylabel('Частота')
    plt.show()

# %% [markdown]
# ##### Промежуточные выводы

# %% [markdown]
# Задача:
# Изучите зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом.
#
# Ответ:
# Явной положительной или отрицательной корреляции (зависимости) между ценой и этажом нет

# %% [markdown]
# #### Изучите зависимость от даты размещения: дня недели, месяца и года.

# %%
#Создаём список, в котором сохраняем названия нужных нам столбцов.
columns_date = ['weekday_of_exposition', 'month_of_exposition', 'year_of_exposition']

#Создаём функцию, которая проходит по столбцам и строит графики.

def cor_data(data, column_group):
    for column in column_group:
        data.pivot_table(index=column, values='last_price').plot(kind='bar', grid=True, color='blueviolet', alpha=.6)
        plt.title('Цены квартиры от ' + column)
        plt.xlabel(column)
        plt.ylabel('last_price')
        plt.show()
        print(df[column].corr(df['last_price']))# Добавляем значение корреляции между столбцами
        print('--------------------------------')
cor_data(df, columns_date)
# Out:
# 0.0013569211122710775
# --------------------------------
# 0.0027259571647347608
# --------------------------------
# -0.042864152713611034
# --------------------------------

# %% [markdown]
# ##### Промежуточные выводы

# %% [markdown]
# Задача: Изучите зависимость от даты размещения: дня недели, месяца и года.
#
#
# Ответ: не прослеживает зависимости от дня недели и от месяца. Что касается года публикации, то с 2014 года по 2018 прослеживается отрицательная динамика. При увеличения года падала цена, что подтверждает отрицательная корреляция -0.042

# %% [markdown]
# ### Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите среди них населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце 'locality_name'.

# %%
#Выбераем10 населённых пунктов с наибольшим числом объявлений. Считаем среднюю цену квадратного метра в этих населённых пунктах
#Создаём сводную таблицу
pivot_squere = df.pivot_table(index='locality_name', values='square_meter_price', aggfunc=['count', 'mean'])

#Даём названия столбцов, чтобы избавиться от мултииндекса
pivot_squere.columns = ['square_meter_price_count', 'square_meter_price_mean']

#Сортируем сводную таблицу
pivot_squere.sort_values('square_meter_price_count', ascending=False, inplace=True)

#Сохраняем топ-10 значений
top_10 = pivot_squere.head(10).reset_index()

print('')
print('Средняя цена квадратного метра в ТОП-10 населённых пунктах по числу объявлений')
display(top_10)


#Создаём новый df, который объединяет две таблицы: топ-10 населённых пунктов по числу объявлений + общий df
#Используем left, чтобы оставить только те города, которые входят в наши топ-10 городов по числу объявлений
top_10_and_df = top_10.merge(df, on='locality_name', how='left')

#Удаляем старые столбцы
top_10_and_df = top_10_and_df.drop(['square_meter_price_count', 'square_meter_price_mean'], 1)

#Строим сводную таблицу по новой таблице
top_10_and_df_price = top_10_and_df.pivot_table(index='locality_name', values='last_price', aggfunc=['count','median'])

#Меняем название столбцов
top_10_and_df_price.columns = ['last_price_count', 'last_price_median']

#Сортируем данные по медианной стоимости квартиры
top_10_and_df_price.sort_values('last_price_median', ascending=False, inplace=True)
print('')
print('Населённые пункты с самой высокой и низкой стоимостью жилья')
display(top_10_and_df_price.reset_index())
# Out:
# Средняя цена квадратного метра в ТОП-10 населённых пунктах по числу объявлений
#      locality_name  square_meter_price_count  square_meter_price_mean
# 0  Санкт-Петербург                     15651               114868.877
# 1           Мурино                       586                86041.116
# 2          Кудрово                       470                95260.846
# 3           Шушары                       439                78551.345
# 4       Всеволожск                       398                68654.474
# 5           Пушкин                       369               103125.819
# 6          Колпино                       338                75424.579
# 7        Парголово                       327                90175.913
# 8          Гатчина                       307                68746.147
# 9           Выборг                       237                58141.909
# Населённые пункты с самой высокой и низкой стоимостью жилья
#      locality_name  last_price_count  last_price_median
# ...

# %% [markdown]
# ##### Промежуточные выводы

# %% [markdown]
# Задача:  Выделите среди них населённые пункты с самой высокой и низкой стоимостью жилья.
#
#
# Ответ:
# Населенные пункты с самой высокой стоимостью жилья: Санкт-Петербург, Пушкин, Парголово.
# Населенные пункты с самой низкой стоимостью жилья: Мурино, Гатчина, Выборг.

# %% [markdown]
# ### Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге ('locality_name'). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона.

# %%
#Создаем новый df, в котором будут строки только с СПБ

spb_flat = df.query('locality_name == "Санкт-Петербург"')

#Создаём новый столбец - расстояние до центра в киломентрах 
spb_flat['city_center_km'] = (spb_flat['cityCenters_nearest'] / 1000)

#Удаляем пустые строки в столбце, чтобы округлить значения
spb_flat.dropna(subset=['city_center_km'], inplace=True)

#Округляем данные в столбце до целого значения
spb_flat['city_center_km'] = spb_flat['city_center_km'].astype('int')

#Строим сводную таблицу
spb_flat_price = spb_flat.pivot_table(index='city_center_km', values='last_price')

display(spb_flat_price.head(10))

#Строим столбчатый график
spb_flat_price.plot(kind='bar', grid=True, color='blueviolet')
plt.title('Цены квартиры от расстояния до центра')
plt.xlabel('Расстояние от центра в км')
plt.ylabel('last_price')
plt.show()
# Out:
#                  last_price
# city_center_km
# 0              23442315.442
# 1              18850851.663
# 2              16163313.616
# 3              13452829.906
# 4              13586091.883
# 5              15305282.736
# 6              14389106.185
# 7              12797673.740
# 8               8430805.777
# 9               6429618.969

# %% [markdown]
# #### Промежуточные выводы:

# %% [markdown]
# Задача: Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона.
#
# Ответ: график сильно меняется между 7 и 8 км. Центр - города в пределах 7 км от центра города.

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Ориентировочно да, потому что дальше идёт в том числе спад и длительная стагнация стоимости.
#
# </div>

# %% [markdown]
# ### Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?

# %% [markdown]
# #### Выделите сегмент квартир в центре.

# %%
#Сохраняем топ-7 км в новый df
spb_flat_price_top_8 = spb_flat_price.head(8).reset_index()

#Объединяем таблицу с основной по столбцу - city_center_km. 
#Также используем объединение слева, чтобы сохранить только те км, которые входят в наш топ. 
flat_in_centr_spb = spb_flat_price_top_8.merge(spb_flat, on='city_center_km', how='left')

#Удаляем старый столбец с ценой
flat_in_centr_spb = flat_in_centr_spb.drop('last_price_x', 1)
display(flat_in_centr_spb.sample(5, random_state=1))
# Out:
#       city_center_km  total_images  last_price_y  total_area  \
# 1644               4             9  20000000.000     128.000
# 2761               5            15  46000000.000     129.000
# 587                2             3   7650000.000      64.000
# 3662               7            19  10900000.000      95.000
# 382                2             8   3500000.000      27.200
#
#      first_day_exposition  rooms  ceiling_height  floors_total  living_area  \
# 1644           2019-04-04      6           3.560             5       86.977
# 2761           2017-02-07      3           3.000            10       81.506
# 587            2017-02-16      2           3.500             5       37.470
# 3662           2017-12-06      3           2.650             4       60.024
# 382            2019-04-29      1           2.800             4       13.128
#
#       floor  is_apartment  studio  open_plan  kitchen_area  balcony  \
# 1644      3         False   False      False        12.653        0
# ...

# %% [markdown]
# ####  Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков.

# %%
#Используем ранее сохданную функцию, которая строит гистограммы по столбцу.
list_of_column = ['total_area', 'last_price_y', 'rooms', 'ceiling_height']
for column in list_of_column:
    hist_list(flat_in_centr_spb, column)
# Out:
# count   3705.000
# mean      92.246
# std       60.491
# min       12.000
# 25%       56.000
# 50%       77.700
# 75%      108.600
# max      900.000
# Name: total_area, dtype: float64
# --------------------------------------------------------------
# count        3705.000
# mean     14722238.842
# std      24723470.204
# min       1600000.000
# 25%       6590000.000
# 50%       9000000.000
# 75%      14100000.000
# max     763000000.000
# Name: last_price_y, dtype: float64
# --------------------------------------------------------------
# count   3705.000
# mean       2.813
# std        1.457
# min        0.000
# 25%        2.000
# 50%        3.000
# 75%        3.000
# max       19.000
# Name: rooms, dtype: float64
# --------------------------------------------------------------
# count   3705.000
# mean       2.944
# std        0.722
# min        2.000
# 25%        2.650
# 50%        2.800
# 75%        3.110
# max       32.000
# Name: ceiling_height, dtype: float64
# ...

# %% [markdown]
# ##### Промежуточные выводы

# %% [markdown]
# Задача: Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков.
#
# Ответ:
# Типичная квартира в центре: 3-х комнатная квартира с потолками 2.80 метра, площадью 77 квадратных метров и ценой 9 000 000
#
# Типичная квартира в общей выборке: 2-х комнатная квартира с потолками 2.65 метра, площадью 52 квадратных метра и ценой -  4 646 000 рублей.
#
# Вывод: в центре СПБ больше площадь, выше потолки и выше цена. За центром - Россия

# %% [markdown]
# #### Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления)

# %%
#Выделим факторы: число комнат, этаж и удалённость от центра). 

#Отобразим столбец корреляции по стоимости квартир. 
display(flat_in_centr_spb.corr()['last_price_y'].sort_values())


#Строим матрицу диграмм рассеивания
corr_price_spb = flat_in_centr_spb[['last_price_y', 'rooms', 'floor', 'cityCenters_nearest']]
pd.plotting.scatter_matrix(corr_price_spb, figsize=(15, 15), marker='x', alpha=0.4, color='black') #Черный цвет - и расхождений в графике нет
display(plt.show())
# Out:
# kit_coef                -0.088
# ponds_nearest           -0.077
# city_center_km          -0.052
# cityCenters_nearest     -0.048
# parks_nearest           -0.046
# year_of_exposition      -0.043
# studio                  -0.023
# liv_coef                -0.018
# month_of_exposition     -0.007
# open_plan                0.008
# weekday_of_exposition    0.023
# days_exposition          0.036
# is_apartment             0.037
# floors_total             0.043
# balcony                  0.063
# ceiling_height           0.071
# airports_nearest         0.094
# ponds_around3000         0.105
# parks_around3000         0.109
# floor                    0.126
# total_images             0.132
# rooms                    0.333
# kitchen_area             0.608
# living_area              0.616
# total_area               0.637
# square_meter_price       0.780
# last_price_y             1.000
# Name: last_price_y, dtype: float64
# None

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Обрати внимание, что наши действия повторяются с точки зрения построения графиков оценки корреляции.
#
# Это говорит о том, что мы можем создать функцию, которая будет выполнять все действия за нас.
#
# Тем самым мы сможем оптимизировать свой код и проект целиком.
#
# </div>

# %% [markdown]
# ##### Промежуточные выводы

# %% [markdown]
# Задача: Выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра)
#
# Ответ: В центре СПБ нет явной положительной корреляции между ценой, числом комнат, этажом или удаленности от центра. Своя экономика, свои правила.

# %%
#Определяем зависимость стоимости квартир в центры от даты размещения 

#Переиспользуем ранее созданную функцию, но меняем в ней пару значений. 
#А менять данные выше не могу, так как уже майские праздники. 

#Создаём список, в котором сохраняем названия нужных нам столбцов.
columns_date = ['weekday_of_exposition', 'month_of_exposition', 'year_of_exposition']

#Создаём функцию, которая проходит по столбцам и строит графики.

def cor_data_2(data, column_group):
    for column in column_group:
        data.pivot_table(index=column, values='last_price_y').plot(kind='bar', grid=True, color='blueviolet', alpha=.6)
        plt.title('Цены квартиры от ' + column)
        plt.xlabel(column)
        plt.ylabel('last_price_y')
        plt.show()
        print(flat_in_centr_spb[column].corr(flat_in_centr_spb['last_price_y']))# Добавляем значение корреляции между столбцами
        print('--------------------------------')
cor_data_2(flat_in_centr_spb, columns_date)
# Out:
# 0.02328719964354931
# --------------------------------
# -0.006547209979317216
# --------------------------------
# -0.04278963151865254
# --------------------------------

# %% [markdown]
# Ответ: у квартир в центре Санкт-не прослеживает зависимости от дня недели и от месяца. Что касается года публикации, то с 2014 года по 2018 прослеживается отрицательная динамика. При увеличения года падала цена, что подтверждает отрицательная корреляция -0.042. Такая же, как и у общего df.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# 1.  По очищенным от выбросов данным, продажа квартиры в среднем занимает 51 день. Если продажа квартиры занимает больше 148 дней (1,5 межквартильного размаха), то можно сказать, что продажа квартиры необычно долгая. По необычно быстрой продажи нет возможности определить, так как выбросов в сторону минимальных значений в очищенных данных не наблюдается. Диаграмма имеет длинный хвост и короткий клюв.
# 2. Зависимость между ценой и площадью квартиры достаточно сильнаая. Коэффициент положительной корреляция Пирсона - 0.825. С увеличением площади квартиры увеличивается стоимость квартиры.
# 3. Стоит также отметить полную корреляцию между жилой площадью квартиры и общей площадью квартиры. Что подтверждает корректность данных.
# 4. Присутствует зависимость между ценой и площадью одно-, двух- и трехкомнатных квартир (см. график - первая строка, второй столбец). Стоимость многокомнатных квартир малопредсказуема - прямолинейной зависимости нет.
# 5. Типичная квартира в центре Санкт-Петербурга: 3-х комнатная квартира с потолками 2.80 метра, площадью 77 квадратных метров и ценой 9 000 000
# 6. Типичная квартира в общей выборке: 2-х комнатная квартира с потолками 2.65 метра, площадью 52 квадратных метра и ценой -  4 646 000 рублей.
# 7. В центре Санкт-Петербурга нет явной положительной корреляции между ценой, числом комнат, этажом или удаленности от центра. Своя экономика, свои правила.
#
#
# Общий вывод по исследовательскому анализу данных собрал в файл с картинками и видеоотзывом. Документ по ссылке - https://vk.cc/8U7VuC

# %% [markdown]
# <div class="alert alert-success">
# <b>Комментарий ревьюера:</b>
#
# Выводы понятны и логичны, а самое главное подкреплены выявленными фактами.
#
# В целом сам проект выполнен на хорошем уровне! На протяжении всей работы чувствуется глубина проработки задачи и это безусловный плюс для нас. Было использовано большое количество методов, которые будут помогать тебе в дальнейших проектах.
#
#
# Поздравляю с успешным завершением проекта 😊👍
#
# И желаю успехов в новых работах 😊
#
# **[общий комментарий]** Не стоит забывать про оформление своей работы, это важный такой же важный этап. Рекомендую «не стесняться» использовать ячейки типа **markdown** там где нам необходимо отобразить свои размышления, в том числе с использованием дополнительной стилизации.
#
# https://sqlbak.com/blog/jupyter-notebook-markdown-cheatsheet
#
# </div>

# %% [markdown]
# ## Чек-лист готовности проекта
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  открыт файл
# - [ ]  файлы изучены (выведены первые строки, метод info())
# - [ ]  определены пропущенные значения
# - [ ]  заполнены пропущенные значения
# - [ ]  есть пояснение, какие пропущенные значения обнаружены
# - [ ]  изменены типы данных
# - [ ]  есть пояснение, в каких столбцах изменены типы и почему
# - [ ]  посчитано и добавлено в таблицу: цена квадратного метра
# - [ ]  посчитано и добавлено в таблицу: день недели, месяц и год публикации объявления
# - [ ]  посчитано и добавлено в таблицу: этаж квартиры; варианты — первый, последний, другой
# - [ ]  посчитано и добавлено в таблицу: соотношение жилой и общей площади, а также отношение площади кухни к общей
# - [ ]  изучены следующие параметры: площадь, цена, число комнат, высота потолков
# - [ ]  построены гистограммы для каждого параметра
# - [ ]  выполнено задание: "Изучите время продажи квартиры. Постройте гистограмму. Посчитайте среднее и медиану. Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?"
# - [ ]  выполнено задание: "Уберите редкие и выбивающиеся значения. Опишите, какие особенности обнаружили."
# - [ ]  выполнено задание: "Какие факторы больше всего влияют на стоимость квартиры? Изучите, зависит ли цена от квадратного метра, числа комнат, этажа (первого или последнего), удалённости от центра. Также изучите зависимость от даты размещения: дня недели, месяца и года. "Выберите 10 населённых пунктов с наибольшим числом объявлений. Посчитайте среднюю цену квадратного метра в этих населённых пунктах. Выделите населённые пункты с самой высокой и низкой стоимостью жилья. Эти данные можно найти по имени в столбце '*locality_name'*. "
# - [ ]  выполнено задание: "Изучите предложения квартир: для каждой квартиры есть информация о расстоянии до центра. Выделите квартиры в Санкт-Петербурге (*'locality_name'*). Ваша задача — выяснить, какая область входит в центр. Создайте столбец с расстоянием до центра в километрах: округлите до целых значений. После этого посчитайте среднюю цену для каждого километра. Постройте график: он должен показывать, как цена зависит от удалённости от центра. Определите границу, где график сильно меняется — это и будет центральная зона. "
# - [ ]  выполнено задание: "Выделите сегмент квартир в центре. Проанализируйте эту территорию и изучите следующие параметры: площадь, цена, число комнат, высота потолков. Также выделите факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления). Сделайте выводы. Отличаются ли они от общих выводов по всему городу?"
# - [ ]  в каждом этапе есть выводы
# - [ ]  есть общий вывод
