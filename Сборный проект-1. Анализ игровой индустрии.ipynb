# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px">
#
# Привет, Мадихан! 👋 Вот и подошел к концу первый модуль 💪
#
# Меня зовут Рустам Муртазин, и я буду делать ревью работы по сборному проекту. Давай будем общаться на **«ты»**. Если это неприемлемо, обязательно напиши мне в комментариях — мы перейдем на **«вы»**.
#
# Я не хочу указавать тебе на совершенные тобою ошибки, а хочу поделиться своим опытом и помочь тебе стать настоящим профессионалом и сделать проект еще лучше.
#
# Обрати внимание в первую очередь на те, что помечаны <span style="color:red">красным цветом</span>. После их доработки проект будет принят. <span style="color:green">Зеленым цветом</span> отмечены удачные и элегантные решения, на которые можно опираться в будущих проектах. <span style="color:orange">Оранжевым цветом</span> выделено то, что в следующий раз можно сделать по-другому. Ты можешь учесть эти комментарии при выполнении будущих заданий или доработать проект сейчас (однако это не обязательно). Также в проекте могут быть небольшие «лайфхаки» по Python, не относящиеся к проекту, их я выделил в фиолетовую рамку)
#
# Давай работать над проектом в диалоге: если ты **что-то меняешь** в проекте по моим рекомендациям — **пиши об этом**. Выбери для своих комментариев какой-то заметный цвет, так мне будет легче отследить изменения. Пожалуйста, **не перемещай, не изменяй и не удаляй мои комментарии**. Всё это поможет выполнить повторную проверку твоего проекта оперативнее».
#
# Мне понравился твой проект, в одном месте его нужно чуть доработать, я оставил комментарии тебе в помощь. После того, как ты все доработаешь, я смогу принять твой проект!) В конце есть чек-лист😉

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# Спасибо тебе, Мадихан, за качественный проект. Такие работы проверять одно удовольствие, чувствуется интерес и стремление к познанию нового.
#
# Работу я, конечно же, принимаю, и желаю удачи в последующих проектах. Надеюсь, мы еще встретимся)
#
# </div>

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Read-the-data" data-toc-modified-id="Read-the-data-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Read the data</a></span><ul class="toc-item"><li><span><a href="#Interim-conclusions" data-toc-modified-id="Interim-conclusions-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Interim conclusions</a></span></li></ul></li><li><span><a href="#Data-preparation" data-toc-modified-id="Data-preparation-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Data preparation</a></span><ul class="toc-item"><li><span><a href="#Распределение-пустых-и-полных-значений-по-годам" data-toc-modified-id="Распределение-пустых-и-полных-значений-по-годам-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Распределение пустых и полных значений по годам</a></span></li><li><span><a href="#Interim-conclusions" data-toc-modified-id="Interim-conclusions-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Interim conclusions</a></span></li></ul></li><li><span><a href="#Data-analysis" data-toc-modified-id="Data-analysis-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Data analysis</a></span><ul class="toc-item"><li><span><a href="#Cколько-игр-выпускалось-в-разные-годы.-Важны-ли-данные-за-все-периоды?" data-toc-modified-id="Cколько-игр-выпускалось-в-разные-годы.-Важны-ли-данные-за-все-периоды?-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Cколько игр выпускалось в разные годы. Важны ли данные за все периоды?</a></span><ul class="toc-item"><li><span><a href="#Interim-conclusions" data-toc-modified-id="Interim-conclusions-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Interim conclusions</a></span></li></ul></li><li><span><a href="#Посмотрите,-как-менялись-продажи-по-платформам.-Выберите-платформы-с-наибольшими-суммарными-продажами-и-постройте-распределение-по-годам.-За-какой-характерный-срок-появляются-новые-и-исчезают-старые-платформы?" data-toc-modified-id="Посмотрите,-как-менялись-продажи-по-платформам.-Выберите-платформы-с-наибольшими-суммарными-продажами-и-постройте-распределение-по-годам.-За-какой-характерный-срок-появляются-новые-и-исчезают-старые-платформы?-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?</a></span><ul class="toc-item"><li><span><a href="#Interim-conclusions" data-toc-modified-id="Interim-conclusions-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Interim conclusions</a></span></li></ul></li><li><span><a href="#Какие-платформы-лидируют-по-продажам,-растут-или-падают?-Выберите-несколько-потенциально-прибыльных-платформ-по-актуальным-данным.-Постройте-график-«ящик-с-усами»-по-глобальным-продажам-игр-в-разбивке-по-платформам.-Опишите-результат." data-toc-modified-id="Какие-платформы-лидируют-по-продажам,-растут-или-падают?-Выберите-несколько-потенциально-прибыльных-платформ-по-актуальным-данным.-Постройте-график-«ящик-с-усами»-по-глобальным-продажам-игр-в-разбивке-по-платформам.-Опишите-результат.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ по актуальным данным. Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.</a></span><ul class="toc-item"><li><span><a href="#Interim-conclusions" data-toc-modified-id="Interim-conclusions-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Interim conclusions</a></span></li></ul></li><li><span><a href="#Посмотрите,-как-влияют-на-продажи-внутри-одной-популярной-платформы-отзывы-пользователей-и-критиков.-Постройте-диаграмму-рассеяния-и-посчитайте-корреляцию-между-отзывами-и-продажами.-Сформулируйте-выводы." data-toc-modified-id="Посмотрите,-как-влияют-на-продажи-внутри-одной-популярной-платформы-отзывы-пользователей-и-критиков.-Постройте-диаграмму-рассеяния-и-посчитайте-корреляцию-между-отзывами-и-продажами.-Сформулируйте-выводы.-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.</a></span><ul class="toc-item"><li><span><a href="#Interim-conclusions" data-toc-modified-id="Interim-conclusions-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Interim conclusions</a></span></li></ul></li><li><span><a href="#Соотнесите-выводы-с-продажами-игр-на-других-платформах." data-toc-modified-id="Соотнесите-выводы-с-продажами-игр-на-других-платформах.-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Соотнесите выводы с продажами игр на других платформах.</a></span><ul class="toc-item"><li><span><a href="#Interim-conclusions" data-toc-modified-id="Interim-conclusions-3.5.1"><span class="toc-item-num">3.5.1&nbsp;&nbsp;</span>Interim conclusions</a></span></li></ul></li><li><span><a href="#Посмотрите-на-общее-распределение-игр-по-жанрам.-Что-можно-сказать-о-самых-прибыльных-жанрах?-Выделяются-ли-жанры-с-высокими-и-низкими-продажами?" data-toc-modified-id="Посмотрите-на-общее-распределение-игр-по-жанрам.-Что-можно-сказать-о-самых-прибыльных-жанрах?-Выделяются-ли-жанры-с-высокими-и-низкими-продажами?-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?</a></span><ul class="toc-item"><li><span><a href="#Interim-conclusions" data-toc-modified-id="Interim-conclusions-3.6.1"><span class="toc-item-num">3.6.1&nbsp;&nbsp;</span>Interim conclusions</a></span></li></ul></li></ul></li><li><span><a href="#Customer-Profiles" data-toc-modified-id="Customer-Profiles-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Customer Profiles</a></span><ul class="toc-item"><li><span><a href="#Портрет-пользователя-из-Северной-Америке" data-toc-modified-id="Портрет-пользователя-из-Северной-Америке-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Портрет пользователя из Северной Америке</a></span><ul class="toc-item"><li><span><a href="#Interim-conclusions" data-toc-modified-id="Interim-conclusions-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Interim conclusions</a></span></li></ul></li><li><span><a href="#Портрет-пользователя-из-Европы" data-toc-modified-id="Портрет-пользователя-из-Европы-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Портрет пользователя из Европы</a></span><ul class="toc-item"><li><span><a href="#Interim-conclusions" data-toc-modified-id="Interim-conclusions-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Interim conclusions</a></span></li></ul></li><li><span><a href="#Портрет-пользователя-из-Японии" data-toc-modified-id="Портрет-пользователя-из-Японии-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Портрет пользователя из Японии</a></span><ul class="toc-item"><li><span><a href="#Interim-conclusions" data-toc-modified-id="Interim-conclusions-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Interim conclusions</a></span></li></ul></li><li><span><a href="#Средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC-одинаковые;" data-toc-modified-id="Средние-пользовательские-рейтинги-платформ-Xbox-One-и-PC-одинаковые;-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;</a></span><ul class="toc-item"><li><span><a href="#Interim-conclusions" data-toc-modified-id="Interim-conclusions-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Interim conclusions</a></span></li></ul></li><li><span><a href="#Средние-пользовательские-рейтинги-жанров-Action-(англ.-«действие»,-экшен-игры)-и-Sports-(англ.-«спортивные-соревнования»)-разные.;" data-toc-modified-id="Средние-пользовательские-рейтинги-жанров-Action-(англ.-«действие»,-экшен-игры)-и-Sports-(англ.-«спортивные-соревнования»)-разные.;-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.;</a></span><ul class="toc-item"><li><span><a href="#Interim-conclusions" data-toc-modified-id="Interim-conclusions-4.5.1"><span class="toc-item-num">4.5.1&nbsp;&nbsp;</span>Interim conclusions</a></span></li></ul></li></ul></li><li><span><a href="#Сonclusion" data-toc-modified-id="Сonclusion-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Сonclusion</a></span></li></ul></div>

# %% [markdown]
# # Сборный проект

# %% [markdown]
# Цель: нужно выявить определяющие успешность игры закономерности. Это позволит сделать ставку на потенциально популярный продукт и спланировать рекламные кампании на 2017 год.
#
# Выборка: Данные о продажах игр, оценки пользователей и экспертов, жанры и платформы (например, Xbox или PlayStation) до 2016 года.
#
# Примечания:
# В наборе данных попадается аббревиатура ESRB (Entertainment Software Rating Board) — это ассоциация, определяющая возрастной рейтинг компьютерных игр. ESRB оценивает игровой контент и присваивает ему подходящую возрастную категорию, например, «Для взрослых», «Для детей младшего возраста» или «Для подростков».
#
# Данные за 2016 год могут быть неполными.

# %% [markdown]
# ## Read the data

# %%
import pandas as pd

# Install options parameters  
pd.options.display.float_format = '{:.2f}'.format
pd.options.display.max_columns = 100

# Turn off warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Install new packages
from mpl_toolkits.mplot3d import Axes3D
from scipy import stats as st
import numpy as np
import matplotlib.pyplot as plt
import datetime
import math
from tqdm import tqdm
from functools import reduce
import seaborn as sns
import plotly.express as px

# %matplotlib inline

# %%
#Import data as df
df = pd.read_csv('/datasets/games.csv')

#Display information about df
display(df.head())
display(df.describe())
duplicates_in_df = df.duplicated().sum()
display(pd.DataFrame(round((df.isna().mean()*100),2)).style.background_gradient('PuBu', low=0.1, high=0.5))
print(f'Amount of diplicates in df: {duplicates_in_df:.1f}')
print('')
df.info()
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii          2006.00        Sports     41.36
# 1         Super Mario Bros.      NES          1985.00      Platform     29.08
# 2            Mario Kart Wii      Wii          2008.00        Racing     15.68
# 3         Wii Sports Resort      Wii          2009.00        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB          1996.00  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45         76.00          8      E
# 1      3.58      6.81         0.77           nan        NaN    NaN
# 2     12.76      3.79         3.29         82.00        8.3      E
# 3     10.93      3.28         2.95         80.00          8      E
# 4      8.89     10.22         1.00           nan        NaN    NaN
#        Year_of_Release  NA_sales  EU_sales  JP_sales  Other_sales  \
# ...

# %% [markdown]
# ### Interim conclusions

# %% [markdown]
# 1. В данных обнаружены пропуски: больше 40% в столбцах: Critic_Score, User_Score и Rating, 1,61% в столбце Year_of_Release.
# 2. Год выпуска игры имеет тип данных float64, заменить на int
# 3. Столбец User Score имеет тип данных object. Есть значением'tbd' в 2424-х строках. TBD - аббревиатура от английского To Be Determined (будет определено) или To Be Decided (будет решено). Используется, если какая-то информация еще не определена или решение по вопросу не принято. Акроним служит для отметки неясностей или пропусков, которые надо заполнить, в информации требований.
# 4. Столбец Critic_Score имеет тип данных float64. Заменить на тип int
# 5. В столбце Rating есть значения с рейтингом, которые имееют только несколько строк (от 1 до 8).
# 6. Дубликатов не обнаружено.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# Хорошее начало! Данные загружены и подробно изучены, отлично подмечены основные проблемы
#
# </div>

# %% [markdown]
# ## Data preparation

# %% [markdown]
# Задачи:
# - Преобразуйте данные в нужные типы. Опишите, в каких столбцах заменили тип данных и почему;
# - Обработайте пропуски при необходимости:
# - Объясните, почему заполнили пропуски определённым образом или почему не стали это делать;
# - Опишите причины, которые могли привести к пропускам;
# - Обратите внимание на аббревиатуру 'tbd' в столбцах с рейтингом. Отдельно разберите это значение и опишите, как его обработать;
# - Посчитайте суммарные продажи во всех регионах и запишите их в отдельный столбец.

# %%
# Renaming columns (lower case)
df.columns = df.columns.str.lower()

# %% [markdown]
# <div class = "alert alert-success">
# <h2> Комментарии ревьюера <a class="tocSkip"> </h2>
#
# Классное решение! И самое короткое
#
# </div>

# %%
# Deleting empty rows in columns 'name', 'year_of_release' and 'genre'
df.dropna(subset=['name','year_of_release', 'genre'], inplace=True) #Empty data less than 1,61%. 
display(pd.DataFrame(round((df.isna().mean()*100),2)).style.background_gradient('PuBu', low=0.1, high=0.5))
# Out:
# <style  type="text/css" >
#     #T_966ce088_f542_11eb_95cc_02420a396446row0_col0 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_966ce088_f542_11eb_95cc_02420a396446row1_col0 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_966ce088_f542_11eb_95cc_02420a396446row2_col0 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_966ce088_f542_11eb_95cc_02420a396446row3_col0 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_966ce088_f542_11eb_95cc_02420a396446row4_col0 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_966ce088_f542_11eb_95cc_02420a396446row5_col0 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_966ce088_f542_11eb_95cc_02420a396446row6_col0 {
#             background-color:  #f5eff6;
#             color:  #000000;
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# Согласен с решением

# %%
# Changing values in column 'user_score'. TBD - To Be Determined > NaN
df['user_score'] = pd.to_numeric(df['user_score'], errors = 'coerce')
df['user_score'].value_counts()
# Out:
# 7.80    322
# 8.00    285
# 8.20    276
# 8.30    252
# 7.50    249
#        ...
# 9.60      2
# 0.60      2
# 1.90      2
# 9.70      1
# 0.00      1
# Name: user_score, Length: 95, dtype: int64

# %% [markdown]
# <div class="alert alert-success">
# <h2>Комментарии ревьюера <a class="tocSkip"> </h2>
#
# Молодец, что не забыл про обработку значений `tbd`. Кстати, здесь отлично подойдет метод [pd.to_numeric](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_numeric.html). Если задать параметр `errors` равным `coerce`, то все значения, которые метод не смог перевести в `float`, он переведет в `nan`
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Roger that, Rustam. </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# 👍

# %%
# Converting the columns to the appropriate types
df['year_of_release'] = df['year_of_release'].astype('int')
df['critic_score'] = df['critic_score'].astype('float')
df['user_score'] = df['user_score'].astype('float')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16444 entries, 0 to 16714
# Data columns (total 11 columns):
# name               16444 non-null object
# platform           16444 non-null object
# year_of_release    16444 non-null int64
# genre              16444 non-null object
# na_sales           16444 non-null float64
# eu_sales           16444 non-null float64
# jp_sales           16444 non-null float64
# other_sales        16444 non-null float64
# critic_score       7983 non-null float64
# user_score         7463 non-null float64
# rating             9768 non-null object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.5+ MB

# %%
# Adding sum revenue
df['sales_world'] = df[['na_sales','eu_sales','jp_sales','other_sales']].sum(axis=1)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# А можно было так
#
#     data[['na_sales','eu_sales','jp_sales','other_sales']].sum(axis=1)

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Roger that, Rustam. </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# Good job

# %%
def hist_box(data, column):
    fig, axes = plt.subplots(nrows=4, 
                             ncols =1, 
                             figsize=(7,15))
    
    data_1 = data[~data[column].isnull()]['year_of_release']
    axes[0].hist(data_1, 
                 alpha=0.5, 
                 bins=30, 
                 color='orange')
    axes[0].grid()
    axes[0].set_ylabel('Частота', fontsize = 12)
    axes[0].set_xlabel('Год релиза', fontsize = 12)
    axes[0].set_title('Распределение значение по столбцу ' + column, fontsize = 14)

    axes[1].boxplot(data_1, 
                    notch=True,
                    sym='o', 
                    vert=False, 
                    widths = 0.1, 
                    patch_artist = True)
    axes[1].set_title('Ящик с усами по значениям в столбце ' + column, fontsize = 14)

    data_2 = data.loc[data[column].isnull()]['year_of_release']
    axes[2].hist(data_2, 
                 alpha=0.5, 
                 bins=30, 
                 color='orange')
    axes[2].grid()
    axes[2].set_ylabel('Частота', fontsize = 12)
    axes[2].set_xlabel('Год релиза', fontsize = 12)
    axes[2].set_title('Распределение пустых значений по столбцу ' + column, fontsize = 14)
    axes[3].boxplot(data_2, 
                    notch=True, 
                    sym='o', 
                    vert=False, 
                    widths = 0.1, 
                    patch_artist = True)
    axes[3].set_title('Ящик с усами по пустым значениям в столбце ' + column, fontsize = 14)
    plt.tight_layout()
    plt.subplots_adjust(0)

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# В целом отличная функция для построения графиков, но я бы боксплоты расположил под (или над) гистограммой, так у них будет единая ось икс.

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> As you wish, Rustam </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# То, что нужно!

# %% [markdown]
# ### Распределение пустых и полных значений по годам

# %%
hist_box(df, 'critic_score')

# %%
hist_box(df, 'user_score')

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# Кстати, если тебе поднадоел стандартный `matplotlib`, попробуй пострить графики с помощью [plotly](https://plotly.github.io/plotly.py-docs/generated/plotly.express.histogram.html)

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Next time I'll try</div>

# %%
hist_box(df, 'rating')

# %% [markdown]
# ### Interim conclusions

# %% [markdown]
# 1. Применили нижний регистр к названиям столбцов.
# 2. Преобразовали данные в тип float и int. В year_of_release заменили на int, чтобы анализировать данные по году выпуска без чисел с плавающей точкой. В столбцах critic_score и user_score заменили тип данных с object на float, чтобы проводить математические операции.
# 3. Удалили строки с пропусками в столбцах name, year_of_release and genre.
# 4. Заменили значения tbd - To Be Determined  на nan.
# 5. В столбцах user_score, rating, critic_score большая часть пропусков приходится на период с 2000 по 2010 гг (график boxplot). Для анализа будем брать актуальный период, который с высокой вероятностью будет после 2010 года.
# 6. Суммарные продажи посчитали. Бог даст - цифры сойдутся.

# %% [markdown]
# ## Data analysis

# %% [markdown]
# Задачи:
# 1. Посмотрите, сколько игр выпускалось в разные годы. Важны ли данные за все периоды?
# 2. Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?
# 3. Возьмите данные за соответствующий актуальный период.
# 4. Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ.
# 5. Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.
# 6. Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.
# 7. Соотнесите выводы с продажами игр на других платформах.
# 8. Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %% [markdown]
# ### Cколько игр выпускалось в разные годы. Важны ли данные за все периоды?

# %%
games_year = df.pivot_table(index='year_of_release', 
                            values='name', 
                            aggfunc=['count'])
games_year.columns = ['count_games']
games_year.sort_values(by='count_games', 
                       ascending=False).T.head(35)
plot = games_year.plot(grid='true', 
                kind='bar', 
                color='blueviolet', figsize=(15, 7))
for rect in plot.patches:
    height = rect.get_height()
    plot.text(rect.get_x() + rect.get_width()/2, 1.01*height, round(height, 2), 
              ha='center', 
              va='bottom', 
              fontsize = 12)
plt.title('Количество выпущенных игр по годам', fontsize=16)
plt.xlabel('Год релиза', fontsize=12)
plt.ylabel('Количество выпущенных игр', fontsize=12)
plt.tight_layout()
plt.subplots_adjust(0)

# %% [markdown]
# #### Interim conclusions

# %% [markdown]
# Больше всего игр выпускалось в 21-ом веке. Пик приходится на 2007-2011 гг. С 2012 года начался спад по объему выпускаемых игр. В 2011 году на рынке появилось 1134 новые игры, в 2012 уже 653 (в два раза меньше), в 2013 - 544, в 2014 году - 581, в 2015 - 606, в 2016 - 502. Для прогноза важны данные за актуальный период, связанный со сроком жизни платформы и игры. Примерно 5 лет. С 2012 по 2016 год.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# 👍

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Thank you</div>

# %% [markdown]
# ### Посмотрите, как менялись продажи по платформам. Выберите платформы с наибольшими суммарными продажами и постройте распределение по годам. За какой характерный срок появляются новые и исчезают старые платформы?

# %%
def sales_region_all_years(data, column, after, before, sales_threshold_on, sales_threshold_sum):
    result = 0
    sample = data.pivot_table(index='platform', 
                              columns='year_of_release', 
                              values=column,aggfunc='sum')
    sample = pd.DataFrame(sample).reset_index()
    sample.fillna(0, inplace=True)
    
    for year in range(after, before):
        result += sample[year]
        
    sample[column] = result
    sample = sample[['platform', column]]
    sample = sample.sort_values(column, ascending=False).head(6)
    display(sample.style.background_gradient(cmap='Blues'))
    
    print('----------------------------------------------------')
    
    sales = data
    sales = sales.loc[(sales[column] >= sales[column].quantile(.03))&
                                    (sales[column] <= sales[column].quantile(.97))]
    sales_platform = sales[(sales['year_of_release'] >after) & 
                           (sales['year_of_release'] <before)]
 
    if sales_threshold_on == 'yes':
        sales_platform = sales_platform.loc[sales_platform[column] > sales_threshold_sum]
    else:
        sales_platform = sales_platform
    ax = sns.catplot(data=sales_platform, 
                     x='year_of_release', 
                     y=column,
                     hue='platform', 
                     kind='box', 
                     aspect=1.5)
    plt.grid(True)
    plt.title(f'Продажи по платформам с {after} по {before} гг', fontsize=14)
    plt.xlabel('Год', fontsize=12)
    plt.ylabel('Мировые продажи, млн. шт', fontsize=12)
    plt.show()

# %%
sales_region_all_years(df, 'sales_world',1980, 1990, 'yes', 1)
# Out:
# <style  type="text/css" >
#     #T_9acc2b48_f542_11eb_95cc_02420a396446row0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_9acc2b48_f542_11eb_95cc_02420a396446row1_col1 {
#             background-color:  #99c7e0;
#             color:  #000000;
#         }    #T_9acc2b48_f542_11eb_95cc_02420a396446row2_col1 {
#             background-color:  #b7d4ea;
#             color:  #000000;
#         }    #T_9acc2b48_f542_11eb_95cc_02420a396446row3_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_9acc2b48_f542_11eb_95cc_02420a396446row4_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_9acc2b48_f542_11eb_95cc_02420a396446row5_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
# ...

# %% [markdown]
# <div style="border:solid purple 5px; padding: 20px">
# <h2 align="center"> Рубрика «Питонячий лайфхакер» <a class="tocSkip"> </h2>
#
# <h3> PEP 8 - руководство по написанию кода на Python  <a class="tocSkip"> </h3>
#
# В python есть своя философия. Именно отсюда берутся определенные правила и стандарты. В пайтон такое соглашение назвали PEP 8 (читается - пэп). PEP 8 создан на основе рекомендаций Гуидо ван Россума (создатель языка Python) с добавлениями от Барри Уорсо (соратник).
#
# Единый стиль оформления делает код понятным для самого программиста и его коллег с разным уровнем подготовки. В идеале наиболее сложный фрагмент кода должен быть понятен с первого прочтения. Это упрощает командную разработку и обучение новичков, позволяет вам быстро возвращаться к собственным давним проектам.
#
# Каждый уважающий себя питонист обязан знать этот стандарт. Читайте [оригинал](https://www.python.org/dev/peps/pep-0008/) или [перевод](https://pythonworld.ru/osnovy/pep-8-rukovodstvo-po-napisaniyu-koda-na-python.html), главное  —  вдумчиво!
#
# Когда проект небольшой, несложно следить за качеством кода, но вот когда проект принимает маштабы ... часто это становиться проблемой. В этом случае выручат скрипты автоматической проверки кода. Кстати, PyCharm проверяет написанное «на лету». А если вы привыкли работать в Jupyter, то на GitHub есть целый раздел [Python Code Quality Authority](https://github.com/PyCQA/), где хранятся утилиты для повышения качества кода, в том числе для проверки стиля на соответствие PEP 8: flake8, pycodestyle, pep8-naming.
#
# ![](https://i.ibb.co/Gv0PvHQ/mini-magick20171220-84-vtyy26.png)

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Roger that, Rustam. Прочитаю на выходных обязательно. В следующем проекте буду писать по правилам PEP 8 </div>

# %% [markdown]
# Доминирование платформы NES

# %%
sales_region_all_years(df, 'sales_world',1990, 1995, 'yes', 1)
# Out:
# <style  type="text/css" >
#     #T_9b71ae24_f542_11eb_95cc_02420a396446row0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_9b71ae24_f542_11eb_95cc_02420a396446row1_col1 {
#             background-color:  #b9d6ea;
#             color:  #000000;
#         }    #T_9b71ae24_f542_11eb_95cc_02420a396446row2_col1 {
#             background-color:  #d9e7f5;
#             color:  #000000;
#         }    #T_9b71ae24_f542_11eb_95cc_02420a396446row3_col1 {
#             background-color:  #d9e8f5;
#             color:  #000000;
#         }    #T_9b71ae24_f542_11eb_95cc_02420a396446row4_col1 {
#             background-color:  #eaf2fb;
#             color:  #000000;
#         }    #T_9b71ae24_f542_11eb_95cc_02420a396446row5_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
# ...

# %% [markdown]
# На смену игровой приставки NES пришёл SNES и сразу стал лидером продаж.

# %%
sales_region_all_years(df, 'sales_world',1995, 2000, 'yes', 1)
# Out:
# <style  type="text/css" >
#     #T_9c395154_f542_11eb_95cc_02420a396446row0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_9c395154_f542_11eb_95cc_02420a396446row1_col1 {
#             background-color:  #bed8ec;
#             color:  #000000;
#         }    #T_9c395154_f542_11eb_95cc_02420a396446row2_col1 {
#             background-color:  #dae8f6;
#             color:  #000000;
#         }    #T_9c395154_f542_11eb_95cc_02420a396446row3_col1 {
#             background-color:  #f0f6fd;
#             color:  #000000;
#         }    #T_9c395154_f542_11eb_95cc_02420a396446row4_col1 {
#             background-color:  #f6faff;
#             color:  #000000;
#         }    #T_9c395154_f542_11eb_95cc_02420a396446row5_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
# ...

# %% [markdown]
# Время SNES ушло. В 1996 год был для них последний. Срок жизни - 5 лет. На рынок пришла SONY с приставкой PS. PC стал сбавлять. Рынок уже никогда не будет прежним

# %%
sales_region_all_years(df, 'sales_world',2000, 2005, 'yes', 2)
# Out:
# <style  type="text/css" >
#     #T_9cfccfe4_f542_11eb_95cc_02420a396446row0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_9cfccfe4_f542_11eb_95cc_02420a396446row1_col1 {
#             background-color:  #b5d4e9;
#             color:  #000000;
#         }    #T_9cfccfe4_f542_11eb_95cc_02420a396446row2_col1 {
#             background-color:  #d0e1f2;
#             color:  #000000;
#         }    #T_9cfccfe4_f542_11eb_95cc_02420a396446row3_col1 {
#             background-color:  #d9e7f5;
#             color:  #000000;
#         }    #T_9cfccfe4_f542_11eb_95cc_02420a396446row4_col1 {
#             background-color:  #dceaf6;
#             color:  #000000;
#         }    #T_9cfccfe4_f542_11eb_95cc_02420a396446row5_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
# ...

# %% [markdown]
# С 2001 по 2005 год - время доминации PS2. С PS попрощались. В тройке лидеров GBA и XB.

# %%
sales_region_all_years(df, 'sales_world',2005, 2010, 'yes', 2)
# Out:
# <style  type="text/css" >
#     #T_9dc0d8a8_f542_11eb_95cc_02420a396446row0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_9dc0d8a8_f542_11eb_95cc_02420a396446row1_col1 {
#             background-color:  #083370;
#             color:  #f1f1f1;
#         }    #T_9dc0d8a8_f542_11eb_95cc_02420a396446row2_col1 {
#             background-color:  #81badb;
#             color:  #000000;
#         }    #T_9dc0d8a8_f542_11eb_95cc_02420a396446row3_col1 {
#             background-color:  #89bedc;
#             color:  #000000;
#         }    #T_9dc0d8a8_f542_11eb_95cc_02420a396446row4_col1 {
#             background-color:  #bdd7ec;
#             color:  #000000;
#         }    #T_9dc0d8a8_f542_11eb_95cc_02420a396446row5_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# Просто космос 🚀 Отличная аналитика
#
# ![](https://i.gifer.com/sbb.gif)
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Thank you</div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# 😊

# %% [markdown]
# PS2 стал сбавлять обороты. На рынок пришли новички - Wiii и DS. Попрощались с GBA и XB. Срок жизни 3-5 лет. С 2007 PS3 начал разгонятся (на графике красный boxplot).

# %%
sales_region_all_years(df, 'sales_world', 2010, 2016, 'yes', 2)
# Out:
# <style  type="text/css" >
#     #T_9e946952_f542_11eb_95cc_02420a396446row0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_9e946952_f542_11eb_95cc_02420a396446row1_col1 {
#             background-color:  #08458a;
#             color:  #f1f1f1;
#         }    #T_9e946952_f542_11eb_95cc_02420a396446row2_col1 {
#             background-color:  #c7dbef;
#             color:  #000000;
#         }    #T_9e946952_f542_11eb_95cc_02420a396446row3_col1 {
#             background-color:  #c7dcef;
#             color:  #000000;
#         }    #T_9e946952_f542_11eb_95cc_02420a396446row4_col1 {
#             background-color:  #d0e2f2;
#             color:  #000000;
#         }    #T_9e946952_f542_11eb_95cc_02420a396446row5_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
# ...

# %% [markdown]
# Лидеры сменились. Wii и DS полностью проиграли PS3 и X360. С 2014 года рынок захватила новая приставка - PS4.

# %%
actual_df = df[df['year_of_release'] > 2011]
actual_df.head()
# Out:
#                           name platform  year_of_release         genre  \
# 16          Grand Theft Auto V      PS3             2013        Action
# 23          Grand Theft Auto V     X360             2013        Action
# 31   Call of Duty: Black Ops 3      PS4             2015       Shooter
# 33         Pokemon X/Pokemon Y      3DS             2013  Role-Playing
# 34  Call of Duty: Black Ops II      PS3             2012       Shooter
#
#     na_sales  eu_sales  jp_sales  other_sales  critic_score  user_score  \
# 16      7.02      9.09      0.98         3.96         97.00        8.20
# 23      9.66      5.14      0.06         1.41         97.00        8.10
# 31      6.03      5.86      0.36         2.38           nan         nan
# 33      5.28      4.19      4.35         0.78           nan         nan
# 34      4.99      5.73      0.65         2.42         83.00        5.30
#
#    rating  sales_world
# 16      M        21.05
# 23      M        16.27
# 31    NaN        14.63
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# Ты верно определил актуальный период 👏
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Thank you</div>

# %% [markdown]
# #### Interim conclusions

# %% [markdown]
# В среднем приставки живут 5 лет. Кто-то доживает дольше и просто существует.

# %% [markdown]
# ### Какие платформы лидируют по продажам, растут или падают? Выберите несколько потенциально прибыльных платформ по актуальным данным. Постройте график «ящик с усами» по глобальным продажам игр в разбивке по платформам. Опишите результат.

# %%
def sales_region_last_5_years(data, column):
    sample = data.loc[data['year_of_release'] > 2011].pivot_table(index='platform', 
                                                                  columns='year_of_release', 
                                                                  values=column,
                                                                  aggfunc='sum')
    sample = pd.DataFrame(sample).reset_index()
    sample.fillna(0, inplace=True)
    sample[column] = sample[2012] + sample[2013] +  sample[2014] + sample[2015] + sample[2016]
    sample = sample.sort_values(column, ascending=False).head(6)
    display(sample.style.background_gradient(cmap='Blues'))
    
    print('---------------------------------------------------------')
    
    top_5 = data.query('platform in(["PS4", "PS3", "X360", "3DS", "XOne"])')
    top_5 = top_5.loc[(top_5[column] >= top_5[column].quantile(.03))&
                                    (top_5[column] <= top_5[column].quantile(.97))]
    top_5_last_5_years = top_5[top_5['year_of_release'] >2011]
    
    ax = sns.catplot(data=top_5_last_5_years, 
                     x='year_of_release', 
                     y=column, 
                     hue='platform', 
                     kind='box',  
                     aspect=2)
    plt.subplots_adjust(0)
    plt.grid(True)
    plt.title(f'Продажи по платформам с 2012 по 2016 гг', fontsize=16)
    plt.xlabel('Год', fontsize=12)
    plt.ylabel('Мировые продажи, млн. шт', fontsize=12)
    plt.show()

# %%
sales_region_last_5_years(actual_df, 'sales_world')
# Out:
# <style  type="text/css" >
#     #T_9f9f6518_f542_11eb_95cc_02420a396446row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_9f9f6518_f542_11eb_95cc_02420a396446row0_col2 {
#             background-color:  #e8f1fa;
#             color:  #000000;
#         }    #T_9f9f6518_f542_11eb_95cc_02420a396446row0_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_9f9f6518_f542_11eb_95cc_02420a396446row0_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_9f9f6518_f542_11eb_95cc_02420a396446row0_col5 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_9f9f6518_f542_11eb_95cc_02420a396446row0_col6 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_9f9f6518_f542_11eb_95cc_02420a396446row1_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
# ...

# %%
box_top5 = actual_df.query('platform in(["PS4", "PS3", "X360", "3DS", "XOne"])')
box_top5 = box_top5.loc[(box_top5['sales_world'] >= box_top5['sales_world'].quantile(.03)) & 
                        (box_top5['sales_world'] <= box_top5['sales_world'].quantile(.97))]
box_top_last_5_years = box_top5[box_top5['year_of_release'] >2011]
ax = sns.catplot(data=box_top_last_5_years, 
                 x='platform', 
                 y='sales_world', 
                 kind='box',
                 aspect=2)
plt.subplots_adjust(0)
plt.grid(True)
plt.title(f'Продажи по платформам за период с 2012 по 2016 гг.', fontsize=16)
plt.xlabel('Год', fontsize=12)
plt.ylabel('Мировые продажи, млн. шт', fontsize=12)
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# Я бы еще добавил боксплоты без разбивки по годам

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Roger that, Rustam. </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# У boxplot есть параметр `showfliers`, который позволяет построить графики без выбросов, может с ними будет еще красивее

# %% [markdown]
# #### Interim conclusions

# %% [markdown]
# По продажам лидирует PS4. Рост наблюдался с 2014 по 2015 год. PS 3 увеличивал продажи с 2012 по 2013 год. После появление приставки нового поколения PS4, PS3 стал демонстрировать отрицательную динамику. Пик популярности другой приставки - X360 приходится на 2012-2013 год. В 2013 году её сменила приставка нового поколения XONE. К сожалению доминация PS4 слишком сильная и она перекрыла все продажи XONE. В целом рынок падает. На графиках boxplot отлична видна просадка с 2013 по 2015 год. Бычий рынок ушёл, на рынок приставок пришли медведи =(

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# Так оно и есть

# %% [markdown]
# ### Посмотрите, как влияют на продажи внутри одной популярной платформы отзывы пользователей и критиков. Постройте диаграмму рассеяния и посчитайте корреляцию между отзывами и продажами. Сформулируйте выводы.

# %%
ps4 = actual_df[actual_df['platform'] =='PS4']

# %%
ps4.plot(kind='scatter', x='user_score', y='sales_world', alpha=0.5, grid=True)
plt.title(f'Диаграмма рассеяния между пользовательский рейтингом и мировыми продажами', fontsize=16)
plt.xlabel('Пользовательский рейтинг', fontsize=12)
plt.ylabel('Мировые продажи, млн. шт', fontsize=12)
plt.tick_params(axis = 'both', which = 'major', labelsize = 12)
plt.subplots_adjust(-1)
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# Для того, чтобы не показывать вспомогательные выводы python типа `<matplotlib.axes._subplots.AxesSubplot at 0x7f5feaf7fc90>`, можно в конце строки добавить точку с запятой или `plt.show()` 😉
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Roger that, Rustam. </div>

# %%
ps4.plot(kind='scatter', x='critic_score', y='sales_world', alpha=0.5, grid=True)
plt.title(f'Диаграмма рассеяния между рейтингом критиков и мировыми продажами пользователей платформы PS4', fontsize=14)
plt.xlabel('Рейтинг критиков', fontsize=12)
plt.ylabel('Мировые продажи, млн. шт', fontsize=12)
plt.tick_params(axis = 'both', which = 'major', labelsize = 12)
plt.subplots_adjust(-1)
plt.show()

# %% [markdown]
# <div class="alert alert-warning">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# Не забывай указывать заголовки и названия осей на графиках. Это необходимо для того, чтобы понять какие именно показатели отображены на графиках (комментарий ко всему проекту).
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Roger that, Rustam. </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# Так намного лучше)

# %%
def cor_plot_and_matrix(data, platform_name):
    platform = data[data['platform'] == platform_name]
    corr_price = platform[['user_score', 'critic_score', 'sales_world']]
    display(platform.corr()['sales_world'].sort_values())
    f, ax = plt.subplots(figsize=(10, 5))
    ax = sns.heatmap(corr_price.corr(), 
                annot = True, 
                vmin=-1, 
                vmax=1, 
                center= 0, 
                cmap= 'coolwarm', 
                linewidths=1, 
                linecolor='black')
    plt.tick_params(axis = 'both', which = 'major', labelsize = 12)
    plt.title('Корреляция между значениями пользователей платформы ' + platform_name, fontsize=14)
    plt.show()
    pd.plotting.scatter_matrix(corr_price, 
                               figsize=(7, 7), 
                               marker='x', 
                               alpha=0.4, 
                               color='black')
    plt.tick_params(axis = 'both', which = 'major', labelsize = 12)
    plt.tight_layout()
    plt.show()

# %%
cor_plot_and_matrix(actual_df, 'PS4')
# Out:
# year_of_release   -0.24
# user_score        -0.03
# critic_score       0.41
# jp_sales           0.53
# na_sales           0.93
# eu_sales           0.96
# other_sales        1.00
# sales_world        1.00
# Name: sales_world, dtype: float64

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# У тебя очень классные функции, здесь я бы тоже что-нибудь придумал, например можно создать функцию, которая по названию платформы строила бы два графика и считала два коэф-та

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Functions is created. </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# Или вот так можно было

# %%
def get_corr_scatter(platform, data):
 
    temporary = data.query('platform == @platform')
    temporary = temporary[['user_score','critic_score','sales_world']]
    
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(16, 5))

    temporary.plot(kind='scatter', x='critic_score', y='sales_world', grid = True, ax=axes[0])
    temporary.plot(kind='scatter', x='user_score', y='sales_world', grid = True, ax=axes[1])
    fig.suptitle(f'Влияние оценки критиков и пользователей на продажи для платформы {platform}')
    
    plt.show()
    
    user_sales = temporary.corr().loc['user_score', 'sales_world']
    crit_sales = temporary.corr().loc['critic_score', 'sales_world']
    
    print (f'Корреляция user_score-sales_world для платформы {platform} равна {round(user_sales, 5)}')
    print (f'Корреляция critic_score-sales_world для платформы {platform} равна {round(crit_sales, 5)}')
    
get_corr_scatter('PS4', actual_df)
# Out:
# Корреляция user_score-sales_world для платформы PS4 равна -0.03196
# Корреляция critic_score-sales_world для платформы PS4 равна 0.40657

# %% [markdown]
# #### Interim conclusions

# %% [markdown]
# Корреляция между продажами и рейтингом пользователей по платформе PS4: 0.03. Между продажами и рейтингом критиков: 0.41. Слабая положительная связь. На 2 графике 3 ряда scatter_matrix можно увидеть, что если рейтинг критиков больше 70, то продажи также возрастают. Возможно и обратное: продажи увеличиваются, рейтинги критиков также возрастают (cash is a king). Если меньше, то зависимости нет.
#
# Также на графике scatter_matrix можно отметить хорошую положительную связь между рейтингом пользователей и критиков. Чем ближе к высоким оценкам, тем чаще мнение пользователей и критиков сходятся.

# %% [markdown]
# ### Соотнесите выводы с продажами игр на других платформах.

# %%
all_platform = actual_df

# %%
all_platform.plot(kind='scatter', x='user_score', y='sales_world', alpha=0.5, grid=True)
plt.title(f'Диаграмма рассеяния между рейтингом пользователей и мировыми продажами по всем платформам', fontsize=14)
plt.xlabel('Рейтинг пользователей', fontsize=12)
plt.ylabel('Мировые продажи, млн. шт', fontsize=12)
plt.tick_params(axis = 'both', which = 'major', labelsize = 12)
plt.subplots_adjust(-1)
plt.show()

# %%
all_platform.plot(kind='scatter', x='critic_score', y='sales_world', alpha=0.5, grid=True)
plt.title(f'Диаграмма рассеяния между рейтингом критиков и мировыми продажами по всем платформам', fontsize=14)
plt.xlabel('Рейтинг критиков', fontsize=12)
plt.ylabel('Мировые продажи, млн. шт', fontsize=12)
plt.tick_params(axis = 'both', which = 'major', labelsize = 12)
plt.subplots_adjust(-1)
plt.show()

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# И с помощью этой функции я бы подтвердил (или нет) свои выводы не на общих данных, а на какой-нибудь другой платформе, например на XOne

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Done </div>

# %%
cor_plot_and_matrix(all_platform, 'XOne')
# Out:
# year_of_release   -0.24
# user_score        -0.07
# critic_score       0.42
# jp_sales           0.45
# eu_sales           0.90
# na_sales           0.97
# other_sales        1.00
# sales_world        1.00
# Name: sales_world, dtype: float64

# %% [markdown]
# #### Interim conclusions

# %% [markdown]
# Корреляция между продажами и рейтингом пользователей по всем платформам: 0.00. Между продажами и рейтингом критиков: 0.31. Слабая положительная связь.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# Молодец! Ты сделал правильно всё, что связано с оценкой корреляции показетелей: построил диаграмму рассеяния, оценил влияние отзывов пользователей и критиков, рассчитал показатель корреляции и объяснил результат, который следует из этого показателя. Так держать!
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Thank you </div>

# %% [markdown]
# ### Посмотрите на общее распределение игр по жанрам. Что можно сказать о самых прибыльных жанрах? Выделяются ли жанры с высокими и низкими продажами?

# %%
genre = actual_df.pivot_table(index='genre', 
                              values='sales_world', 
                              aggfunc='sum').sort_values('sales_world', ascending=False)
display(genre.style.background_gradient(cmap='Blues'))
plot = genre.plot(kind='bar', 
                  grid=True, 
                  ylim=0, 
                  legend=True,
                  figsize=(15,7),
                  color='orange')
for rect in plot.patches:
    height = rect.get_height()
    plot.text(rect.get_x() + rect.get_width()/2, 1.01*height, round(height, 2), ha='center', va='bottom', fontsize = 12)
plt.ylabel('Мировые продажи, млн. шт', fontsize = 16)
plt.xlabel('Жанр', fontsize = 16)
plt.tick_params(axis = 'both', which = 'major', labelsize = 16)
plt.title('Продажи по жанрам', fontsize = 22)
plt.show()
# Out:
# <style  type="text/css" >
#     #T_a560f430_f542_11eb_95cc_02420a396446row0_col0 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_a560f430_f542_11eb_95cc_02420a396446row1_col0 {
#             background-color:  #3282be;
#             color:  #000000;
#         }    #T_a560f430_f542_11eb_95cc_02420a396446row2_col0 {
#             background-color:  #87bddc;
#             color:  #000000;
#         }    #T_a560f430_f542_11eb_95cc_02420a396446row3_col0 {
#             background-color:  #92c4de;
#             color:  #000000;
#         }    #T_a560f430_f542_11eb_95cc_02420a396446row4_col0 {
#             background-color:  #d3e3f3;
#             color:  #000000;
#         }    #T_a560f430_f542_11eb_95cc_02420a396446row5_col0 {
#             background-color:  #deebf7;
#             color:  #000000;
#         }    #T_a560f430_f542_11eb_95cc_02420a396446row6_col0 {
#             background-color:  #e1edf8;
#             color:  #000000;
# ...

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# А можно было значения из таблицы изобразить на графике, вот пример как)

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Done </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# 👏

# %%
plot = genre.plot(kind='bar', grid=True, ylim=0, legend=False,color='purple', figsize=(15, 7))

for rect in plot.patches:
    height = rect.get_height()
    plot.text(rect.get_x() + rect.get_width()/2, 1.01*height, round(height, 2), ha='center', va='bottom', fontsize = 12)

plt.ylabel('sales_world', fontsize = 16)
plt.xlabel('genre', fontsize = 16)
plt.tick_params(axis = 'both', which = 'major', labelsize = 16)
plt.title('Sales_world for genre', fontsize = 22)
plt.show()

# %% [markdown]
# #### Interim conclusions

# %% [markdown]
# Самые прибыльные жанры Action и Shooter. На них приходится 51% от всех продаж. Сидят на голодной пайке разработчики стратегий и пазлов.

# %% [markdown]
# ## Customer Profiles

# %% [markdown]
# Задачи:
# Определите для пользователя каждого региона (NA, EU, JP):
# - Самые популярные платформы (топ-5). Опишите различия в долях продаж.
# - Самые популярные жанры (топ-5). Поясните разницу.
# - Влияет ли рейтинг ESRB на продажи в отдельном регионе?

# %%
actual_df['rating'].fillna('no_rating', inplace=True)

# %%
# Где мог - написал по-английски. Сейчас устал. Пишу по-русски. 
# Добавляем цифру вместо рейтинга, чтобы рассчитать корреляцию. 
def category_rating(data): 
    rating = data['rating']
    if rating == 'E':
        return 1
    elif rating == 'E10+':
        return 2
    elif rating =='M':
        return 3
    elif rating == 'T':
        return 4
    elif rating =='no_rating':
        return 5
    return 0
actual_df['category_rating'] = actual_df.apply(category_rating, axis=1)

# %%
def user_region_portret(data,column):
    print('Most popular platform in '+column)
    sales_region_last_5_years(data,column)
    print('---------------------------------------------------------')
    print('')
    print('Most popular genre in '+column)
    genre_region = data.pivot_table(index='genre', 
                                    values=column, 
                                    aggfunc=['count','sum', 'median'])
    genre_region.columns = ['count_' + column, 'sum_' + column, 'median' + column]
    genre_region = genre_region.sort_values('sum_' + column, ascending=False).head()
    display(genre_region.style.background_gradient(cmap='Blues'))
    
    print('---------------------------------------------------------')
    
    genre_region['sum_' + column].plot(kind='bar',
                                       grid=True, 
                                       ylim=0, 
                                       legend=True,color='blueviolet')
    plt.xlabel('Жанр игры', fontsize=12)
    plt.title('Продажи по жанрам', fontsize=14)
    plt.ylabel('Мировые продажи, млн. шт в ' + column, fontsize=12)
    plt.show()
    
    print('---------------------------------------------------------')
    
    print('')
    print('Rating affection on '+column)
    
    rating_region = data.pivot_table(index='rating', 
                                     values=column, 
                                     aggfunc=['count','sum', 'median'])
    display(rating_region.style.background_gradient(cmap='Blues'))
    rating_region['sum'].plot(kind='bar',
                              grid=True, 
                              ylim=0, 
                              legend=True,
                              color='orange')
    plt.xlabel('Возрастной рейтинг игры', fontsize=12)
    plt.title('Продажи по рейтингам', fontsize=14)
    plt.ylabel('Мировые продажи, млн. шт в ' + column, fontsize=12)
    plt.show()
    cor_rating = actual_df['category_rating'].corr(actual_df[column])
    print('---------------------------------------------------------')
    print('Correlation between rating and',column,' {:.3f}'.format(cor_rating))

# %% [markdown]
# ### Портрет пользователя из Северной Америке

# %%
user_region_portret(actual_df, 'na_sales')
# Out:
# Most popular platform in na_sales
# <style  type="text/css" >
#     #T_a62e1280_f542_11eb_95cc_02420a396446row0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_a62e1280_f542_11eb_95cc_02420a396446row0_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_a62e1280_f542_11eb_95cc_02420a396446row0_col3 {
#             background-color:  #94c4df;
#             color:  #000000;
#         }    #T_a62e1280_f542_11eb_95cc_02420a396446row0_col4 {
#             background-color:  #eaf3fb;
#             color:  #000000;
#         }    #T_a62e1280_f542_11eb_95cc_02420a396446row0_col5 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_a62e1280_f542_11eb_95cc_02420a396446row0_col6 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_a62e1280_f542_11eb_95cc_02420a396446row1_col1 {
#             background-color:  #f7fbff;
# ...

# %% [markdown]
# <div class="alert alert-danger">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# Отличная работа! Но в данном разделе ты не учел продажи без рейтингов (при выборе ТОП рейтингов). В одном из регионов они занимают лидирующие позиции, добавь пожалуйста, и предположи, с чем это может быть связано
#
# </div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Done </div>

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера v2 <a class="tocSkip"> </h2>
#
# Супер, идем дальше

# %% [markdown]
# #### Interim conclusions

# %% [markdown]
# Пользователь из Северной Америки пользуется приставкой X360 или PS4. Из жанров предпочитает Action и Shooter (как и все). Корреляция между возрастным рейтингом от ESRB и продажами: 0.150, то есть связь практически отсутствует.

# %% [markdown]
# ### Портрет пользователя из Европы

# %%
user_region_portret(actual_df, 'eu_sales')
# Out:
# Most popular platform in eu_sales
# <style  type="text/css" >
#     #T_a83aa02a_f542_11eb_95cc_02420a396446row0_col1 {
#             background-color:  #f7fbff;
#             color:  #000000;
#         }    #T_a83aa02a_f542_11eb_95cc_02420a396446row0_col2 {
#             background-color:  #d9e7f5;
#             color:  #000000;
#         }    #T_a83aa02a_f542_11eb_95cc_02420a396446row0_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_a83aa02a_f542_11eb_95cc_02420a396446row0_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_a83aa02a_f542_11eb_95cc_02420a396446row0_col5 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_a83aa02a_f542_11eb_95cc_02420a396446row0_col6 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_a83aa02a_f542_11eb_95cc_02420a396446row1_col1 {
#             background-color:  #08306b;
# ...

# %% [markdown]
# #### Interim conclusions

# %% [markdown]
# Пользователь из Европы предпочитает приставки от Sony. Лидеры продаж PS3 и PS4. Из жанров без изменений: Action и Shooter. Корреляция между возрастным рейтингом от ESRB и продажами: 0.130, то есть связь практически отсутствует.

# %% [markdown]
# ### Портрет пользователя из Японии

# %%
user_region_portret(actual_df, 'jp_sales')
# Out:
# Most popular platform in jp_sales
# <style  type="text/css" >
#     #T_a991a0a4_f542_11eb_95cc_02420a396446row0_col1 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_a991a0a4_f542_11eb_95cc_02420a396446row0_col2 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_a991a0a4_f542_11eb_95cc_02420a396446row0_col3 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_a991a0a4_f542_11eb_95cc_02420a396446row0_col4 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_a991a0a4_f542_11eb_95cc_02420a396446row0_col5 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_a991a0a4_f542_11eb_95cc_02420a396446row0_col6 {
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }    #T_a991a0a4_f542_11eb_95cc_02420a396446row1_col1 {
#             background-color:  #4b98ca;
# ...

# %% [markdown]
# #### Interim conclusions

# %% [markdown]
# Пользователь из Японии живёт вне мировых тенденций. Пользуется приставками 3DS и PS3. Играет в Role-Playing, Action и Mis. Корреляция между возрастным рейтингом от ESRB и продажами: -0.061. То есть связь практически отсутствует.

# %% [markdown]
# # Hypothesis tests

# %% [markdown]
# Проверьте гипотезы:
# - Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;
# - Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.
# Задайте самостоятельно пороговое значение alpha.
# Поясните:
# - Как вы сформулировали нулевую и альтернативную гипотезы;
# - Какой критерий применили для проверки гипотез и почему.

# %% [markdown]
# <div style="border:solid purple 5px; padding: 20px">
# <h2 align="center"> Рубрика «Питонячий лайфхакер» <a class="tocSkip"> </h2>
#
# <h3> Библиотека os <a class="tocSkip"> </h3>
#
# Модуль os в Python — это библиотека функций для работы с операционной системой. Методы, включенные в неё позволяют определять тип операционной системы, получать доступ к переменным окружения, управлять директориями и файлами:
#
# - проверка существования объекта по заданному пути;
# - определение размера в байтах;
# - удаление;
# - переименование и др.
#
# Библиотека довольно обширная, при желании, можно почитать [официальную документацию](https://docs.python.org/3/library/os.html), либо короткий [перевод](https://pythonworld.ru/moduli/modul-os.html). Вот некоторые методы этой библиотеки
#
# Чтобы узнать, какая она на вашей операционной системе, используется функция `getcwd`
#
# ![](https://i.ibb.co/4RYXGqV/image.png)
#
# Функция `chdir` сменит ее на другую, которая будет указана аргументом
#
# ![](https://i.ibb.co/rwM0WY8/image.png)
#
# Функция `listdir` без указания аргумента покажет все файлы и папки текущей рабочей директории. Можно также указать аргументом интересующий вас путь
#
# ![](https://i.ibb.co/4pWQ16Y/image.png)
#
# Чтобы создать папку, применяется функция `mkdir`. Эта функция сможет создать только одну папку в существующем пути, если указанного пути не существует, то вызовется ошибка. Если папка уже существует - вызовется ошибка
#
# ![](https://i.ibb.co/q53Z6YD/image.png)

# %%
def mean_disctibution(column, a_group, b_group):
    a_rating = []
    b_rating = []
    df_a = actual_df[(actual_df[column] == a_group) & (~actual_df['user_score'].isna())]
    df_b = actual_df[(actual_df[column] ==b_group) &(~actual_df['user_score'].isna())]
    len_a = len(df_a)
    len_b = len(df_b)
    for _ in tqdm(range(10000)):
        sample_a = np.random.choice(df_a['user_score'], size=len_a, replace=True)
        sample_b = np.random.choice(df_b['user_score'], size=len_b, replace=True)
        a_rating.append(sample_a.mean())
        b_rating.append(sample_b.mean())
    fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(15,5))
    ax.set_title('Group A (blueviolet) and B (orange) distribution of averages')
    ax.hist(a_rating, bins=100, color='blueviolet', alpha=0.5)
    ax.hist(b_rating, bins=100, color='orange', alpha=0.5)
    fig.tight_layout()

# %%
def distribution_ttest(data, column, alpha, a_group, b_group):
    data = data[~data['user_score'].isna()]
    sample_a = data[data[column]==a_group]['user_score']
    sample_b = data[data[column]==b_group]['user_score']
    
    print('H0 - данные по столбцу', column,'распределены нормально')
    print('H1 - данные по столбцу', column,'распределены не нормально')
    
    print('')
    x1,y1 = st.shapiro(sample_a)
    print('p-value', y1)
    if y1 < alpha: 
        print('Отвергаем нулевую гипотезу о нормальности распределения по столбцу user_score значений ' + a_group)
    else: 
        print('Не удалось отвергнуть нулевую гипотезу о нормальности распределения по столбцу user_score значений ' + a_group)
    
    x2,y2 = st.shapiro(sample_b)
    print('')
    print('p-value', y2)
    if y2 < alpha: 
        print('Отвергаем нулевую гипотезу о нормальности распределения по столбцу user_score значений ' + b_group)
    else: 
        print('Не удалось отвергнуть нулевую гипотезу о нормальности распределения по столбцу user_score значений ' + b_group)
        
    print('')
    print('H0 - дисперсии выборок по столбцу user_score равны')
    print('H1 - дисперсии выборок по столбцу user_score не равны')
    
    print('')
    results_levene = st.levene(sample_a, sample_b)
    print('p-значение:', results_levene.pvalue)
    if (results_levene.pvalue < alpha):
        print('Отвергаем нулевую гипотезу о равенстве дисперсии выборок')
    else: 
        print('Не получилось отвергнуть нулевую гипотезу о равенстве дисперсии выборок')
    results = st.ttest_ind(sample_a,sample_b,equal_var = False)
    
    print('')
    print('H0 - средние значения выборок по столбцу user_score равны')
    print('H1 - средние значения выборок по столбцу user_score не равны')
    
    print('')
    print('p-value', results.pvalue)
    if results.pvalue < alpha: 
        print('Отвергаем нулевую гипотезу о равенстве двух средних')
    else: 
        print('Не удалось отвергнуть нулевую гипотезу о равенстве двух средних')

# %% [markdown]
# ### Средние пользовательские рейтинги платформ Xbox One и PC одинаковые;

# %%
mean_disctibution('platform', 'PC', 'XOne')
distribution_ttest(actual_df, 'platform', 0.05, 'PC', 'XOne')
# Out:
# 100%|██████████| 10000/10000 [00:04<00:00, 2300.16it/s]
# H0 - данные по столбцу platform распределены нормально
# H1 - данные по столбцу platform распределены не нормально
#
# p-value 1.141219598821408e-07
# Отвергаем нулевую гипотезу о нормальности распределения по столбцу user_score значений PC
#
# p-value 1.524856543255737e-05
# Отвергаем нулевую гипотезу о нормальности распределения по столбцу user_score значений XOne
#
# H0 - дисперсии выборок по столбцу user_score равны
# H1 - дисперсии выборок по столбцу user_score не равны
#
# p-значение: 0.01251484281850554
# Отвергаем нулевую гипотезу о равенстве дисперсии выборок
#
# H0 - средние значения выборок по столбцу user_score равны
# H1 - средние значения выборок по столбцу user_score не равны
#
# p-value 0.5489537965134912
# Не удалось отвергнуть нулевую гипотезу о равенстве двух средних

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# Превосходно 👏

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Thank you, Rustam </div>

# %% [markdown]
# #### Interim conclusions

# %% [markdown]
# Гипотезу о равенстве двух средних не удалось отвергнуть. Полученное значение p-value говорит о том, что средний пользовательский рейтинг платформ PS и XONE отличается, но с вероятностью в почти 54% такое различие можно получить случайно. Это слишком высокая вероятность для того, чтобы делать выводы о значимом различии между средними значениями рейтинга.

# %% [markdown]
# ### Средние пользовательские рейтинги жанров Action (англ. «действие», экшен-игры) и Sports (англ. «спортивные соревнования») разные.;

# %%
mean_disctibution('genre', 'Action', 'Sports')
distribution_ttest(actual_df, 'genre', 0.05, 'Action', 'Sports')
# Out:
# 100%|██████████| 10000/10000 [00:03<00:00, 3177.60it/s]
# H0 - данные по столбцу genre распределены нормально
# H1 - данные по столбцу genre распределены не нормально
#
# p-value 8.147253239358982e-17
# Отвергаем нулевую гипотезу о нормальности распределения по столбцу user_score значений Action
#
# p-value 0.0002625079359859228
# Отвергаем нулевую гипотезу о нормальности распределения по столбцу user_score значений Sports
#
# H0 - дисперсии выборок по столбцу user_score равны
# H1 - дисперсии выборок по столбцу user_score не равны
#
# p-значение: 1.3125789036876737e-05
# Отвергаем нулевую гипотезу о равенстве дисперсии выборок
#
# H0 - средние значения выборок по столбцу user_score равны
# H1 - средние значения выборок по столбцу user_score не равны
#
# p-value 4.24307776572644e-20
# Отвергаем нулевую гипотезу о равенстве двух средних

# %% [markdown]
# #### Interim conclusions

# %% [markdown]
# Гипотеза о равенстве средних пользовательских оценок жанров Action и Sports отклонена. Полученное значение p-value говорит о том, что вероятность получить такие же значения случайно 4.24307776572644e-20. Примерно такой же шанс выиграть в лотерею.

# %% [markdown]
# ## Сonclusion

# %% [markdown]
# Успешность игры зависит от многих факторов. Рекомендую сделать ставку на жанр Action и Sport, среди платформ на PS4 и XONE. Также стоит сделать версию для Японии на платформе 3DS. По рейтингам - на них сильно ориентироваться не стоит. Корреляции между продажами и рейтингами слабая. Вывод: делайте хороший продукт и всё будет.

# %% [markdown]
# <div class="alert alert-success">
# <h2> Комментарий ревьюера <a class="tocSkip"> </h2>
#
# С последним не поспоришь)

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарий студента:</b> Thank you, Rustam </div>

# %% [markdown]
# <div style="border:solid purple 2px; padding: 20px">
#
# Работа выполнена на высоком уровне, ты хорошо используешь изученный материал, отлично визуализируешь графики, на каждом шаге аргументируешь свой выбор. Мне понравился твой очень вдумчивый подход к работе.
#
# Остались небольшие доработки:
#
# - В шаге 4 дополнить аналитику по играм с пустыми рейтингами;
#
# Я уверен, ты легко справишься с доработками, жду твоих исправлений 😊
